# %%
import os
import warnings

warnings.filterwarnings("ignore")
if 'run' in os.getcwd():
    os.chdir('..')
    
os.environ["CUDA_VISIBLE_DEVICES"] = "0" # Possible GPUS

# %%
SAMPLE = 0 # unconditional
MODE = "generation"
NAME = 'SIGMA_MIN_1e-4'
PRED_MODE = 'vp'
SAMPLER = 'sde'
SIGMA_MIN = 0.0001
SIGMA_MAX = 1
KERNEL_TYPE= 'rbf'
RESULT = "./results/result_best_gp.csv"

# %%
best_hyperparams = {}

# %%
#BETA_MIN, BETA_MAX, SIGMA_DATA, VAR
best_hyperparams['energy'] = (0.2, 10, 0.05, 1)
best_hyperparams['etth'] = (0.2, 10, 0.1, 0.5)
best_hyperparams['fmri'] = (0.1, 2, 0.5,  0.1)
best_hyperparams['mujoco'] = (0.1, 5, 0.5, 0.1)
best_hyperparams['sines'] = (0.2, 10, 0.5, 1)
best_hyperparams['stock'] = (0.2, 10, 0.1,  0.3)

# %%
NAME = 'BRIDGE-TS-BEST'
PRIOR = 'gp'
BW = 'GAUSSIAN'

for DATA in ['energy', 'etth', 'fmri', 'mujoco', 'sines', 'stock']:
    BETA_MIN, BETA_MAX, SIGMA_DATA, VAR = best_hyperparams[DATA]
    print(best_hyperparams[DATA], DATA)
    
    NAME_ = DATA + "_" + PRED_MODE + "_" + SAMPLER + "_" + NAME + "_" + PRIOR + "_" + KERNEL_TYPE + "_" + str(VAR) + "_" +  BW + "_BETA" + str(BETA_MIN) + "_" + str(BETA_MAX)+"_"+ str(SIGMA_DATA) 
    
    # !python main.py --data {DATA} --name {NAME_} --sample {SAMPLE} --mode {MODE} --train --pred_mode {PRED_MODE} --sampler {SAMPLER} --prior {PRIOR} \
    --sigma_min {SIGMA_MIN} --sigma_max {SIGMA_MAX} --sigma_data {SIGMA_DATA} --beta_min {BETA_MIN} --beta_d {BETA_MAX}  --result_csv {RESULT} --model_matching "D_matching" \
    --kernel_type {KERNEL_TYPE} --bw {BW} --var {VAR}
    
    # !python main.py --data {DATA} --name {NAME_} --sample {SAMPLE} --mode {MODE} --eval --pred_mode {PRED_MODE} --sampler {SAMPLER} --prior {PRIOR} \
    --sigma_min {SIGMA_MIN} --sigma_max {SIGMA_MAX} --sigma_data {SIGMA_DATA} --beta_min {BETA_MIN} --beta_d {BETA_MAX}  --result_csv {RESULT} --model_matching "D_matching" \
    --kernel_type {KERNEL_TYPE} --bw {BW} --var {VAR}
     
print(f'Trained with {NAME_}')
print('*'*20)
# Out:
# (0.2, 10, 0.05, 1) energy
# 2026-02-05 01:03:49.935342: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-05 01:03:49.966674: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.05 beta with 0.2 10.0
# pred with:  vp
# churn ratio 0.33
# {'overall': {'trainable': '1.09M', 'non_trainable': '0', 'total': '1.09M'}, 'model': {'trainable': '1.09M', 'non_trainable': '0', 'total': '1.09M'}}
# energy_vp_sde_BRIDGE-TS-BEST_gp_rbf_1_GAUSSIAN_BETA0.2_10_0.05: start training...
# loss: 66.286839: 100%|████████████████████| 25000/25000 [51:10<00:00,  4.18it/s]
# ============================================================
# ============================================================
#
# loss: 66.286839: 100%|████████████████████| 25000/25000 [51:10<00:00,  8.14it/s]
# training complete loss: 66.286839
# Training done, time: 3070.31
# 2026-02-05 01:55:08.964549: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-05 01:55:09.006831: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.05 beta with 0.2 10.0
# pred with:  vp
# churn ratio 0.33
# {'overall': {'trainable': '1.09M', 'non_trainable': '0', 'total': '1.09M'}, 'model': {'trainable': '1.09M', 'non_trainable': '0', 'total': '1.09M'}}
# Begin to sample...
# Sampling time steps 40
# sampling with NFE: 119
# 1111 torch.Size([2001, 24, 28]) torch.Size([2001, 24, 28])
# 2222 torch.Size([2001, 24, 28]) torch.Size([2001, 24, 28])
# Sampling time steps 40
# sampling with NFE: 119
# 1111 torch.Size([2001, 24, 28]) torch.Size([2001, 24, 28])
# 2222 torch.Size([2001, 24, 28]) torch.Size([2001, 24, 28])
# Sampling time steps 40
# sampling with NFE: 119
# 1111 torch.Size([2001, 24, 28]) torch.Size([2001, 24, 28])
# 2222 torch.Size([2001, 24, 28]) torch.Size([2001, 24, 28])
# Sampling time steps 40
# sampling with NFE: 119
# 1111 torch.Size([2001, 24, 28]) torch.Size([2001, 24, 28])
# 2222 torch.Size([2001, 24, 28]) torch.Size([2001, 24, 28])
# Sampling time steps 40
# sampling with NFE: 119
# 1111 torch.Size([2001, 24, 28]) torch.Size([2001, 24, 28])
# 2222 torch.Size([2001, 24, 28]) torch.Size([2001, 24, 28])
# Sampling time steps 40
# sampling with NFE: 119
# 1111 torch.Size([2001, 24, 28]) torch.Size([2001, 24, 28])
# 2222 torch.Size([2001, 24, 28]) torch.Size([2001, 24, 28])
# Sampling time steps 40
# sampling with NFE: 119
# 1111 torch.Size([2001, 24, 28]) torch.Size([2001, 24, 28])
# 2222 torch.Size([2001, 24, 28]) torch.Size([2001, 24, 28])
# Sampling time steps 40
# sampling with NFE: 119
# 1111 torch.Size([2001, 24, 28]) torch.Size([2001, 24, 28])
# 2222 torch.Size([2001, 24, 28]) torch.Size([2001, 24, 28])
# Sampling time steps 40
# sampling with NFE: 119
# 1111 torch.Size([2001, 24, 28]) torch.Size([2001, 24, 28])
# 2222 torch.Size([2001, 24, 28]) torch.Size([2001, 24, 28])
# Sampling time steps 40
# sampling with NFE: 119
# 1111 torch.Size([2001, 24, 28]) torch.Size([2001, 24, 28])
# 2222 torch.Size([2001, 24, 28]) torch.Size([2001, 24, 28])
# Sampling done, time: 125.51, with samples (20010, 24, 28)
# Iter 0
#
# context-fid = 0.07825619482717878
#
# cross-correlation = 0.7589979163979659
#
# WARNING:tensorflow:From /app/Utils/discriminative_metric.py:103: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/src/layers/rnn/legacy_cells.py:585: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/src/layers/rnn/legacy_cells.py:599: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /app/Utils/discriminative_metric.py:107: all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Please use tf.global_variables instead.
# 2026-02-05 01:57:49.129707: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# training: 100%|█████████████████████████████| 2000/2000 [00:37<00:00, 53.66it/s]
# discriminative_score = 0.22685772254628456 with fake/real 0.8006593963986812 0.6530560486938879
#
# training: 100%|█████████████████████████████| 5000/5000 [01:25<00:00, 58.64it/s]
# predictive_score = 0.25075823478214876
#
# Iter 1
#
# context-fid = 0.09451099323620155
#
# cross-correlation = 0.9322070307355755
#
# training: 100%|█████████████████████████████| 2000/2000 [00:35<00:00, 56.23it/s]
# discriminative_score = 0.21316256657367483 with fake/real 0.7917829064164342 0.6345422267309155
#
# training: 100%|█████████████████████████████| 5000/5000 [01:24<00:00, 59.39it/s]
# predictive_score = 0.2508240290660388
#
# Iter 2
#
# context-fid = 0.07826202446786576
#
# cross-correlation = 0.7820371681314603
#
# training: 100%|█████████████████████████████| 2000/2000 [00:36<00:00, 55.28it/s]
# discriminative_score = 0.22406796855186406 with fake/real 0.7628709104742581 0.68526502662947
#
# training: 100%|█████████████████████████████| 5000/5000 [01:24<00:00, 59.23it/s]
# predictive_score = 0.25091079043325676
#
# Iter 3
#
# context-fid = 0.08821879879905205
#
# cross-correlation = 1.1520413971754588
#
# training: 100%|█████████████████████████████| 2000/2000 [00:35<00:00, 56.24it/s]
# discriminative_score = 0.2266041085467918 with fake/real 0.6794319046411362 0.7737763124524474
#
# training: 100%|█████████████████████████████| 5000/5000 [01:23<00:00, 59.64it/s]
# predictive_score = 0.25107924167450374
#
# Iter 4
#
# context-fid = 0.08407490642658196
#
# cross-correlation = 1.080363515798756
#
# training: 100%|█████████████████████████████| 2000/2000 [00:35<00:00, 56.10it/s]
# discriminative_score = 0.23471975653056054 with fake/real 0.7907684504184631 0.6786710626426579
#
# training: 100%|█████████████████████████████| 5000/5000 [01:23<00:00, 59.93it/s]
# predictive_score = 0.25087040567982705
#
# Context-Fid Final Score:  0.08466458355137602 ± 0.008602324835074223
# Cross-Correlation Final Score:  0.9411294056478432 ± 0.21723073446486496
# Discriminative Final Score:  0.22508242454983515 ± 0.009647048244698616
# Predictive Final Score:  0.250888540327155 ± 0.00014994368373912433
# Traceback (most recent call last):
#   File "main.py", line 342, in <module>
#     main()
#   File "main.py", line 335, in main
#     df.to_csv(args.result_csv, index=False, mode='w', encoding='utf-8-sig')
#   File "/usr/local/lib/python3.8/dist-packages/pandas/core/generic.py", line 3772, in to_csv
#     return DataFrameRenderer(formatter).to_csv(
#   File "/usr/local/lib/python3.8/dist-packages/pandas/io/formats/format.py", line 1186, in to_csv
#     csv_formatter.save()
#   File "/usr/local/lib/python3.8/dist-packages/pandas/io/formats/csvs.py", line 240, in save
#     with get_handle(
#   File "/usr/local/lib/python3.8/dist-packages/pandas/io/common.py", line 737, in get_handle
#     check_parent_directory(str(handle))
#   File "/usr/local/lib/python3.8/dist-packages/pandas/io/common.py", line 600, in check_parent_directory
#     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
# OSError: Cannot save file into a non-existent directory: 'results'
# (0.2, 10, 0.1, 0.5) etth
# 2026-02-05 02:10:26.036290: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-05 02:10:26.070004: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.1 beta with 0.2 10.0
# pred with:  vp
# churn ratio 0.33
# {'overall': {'trainable': '345.25K', 'non_trainable': '0', 'total': '345.25K'}, 'model': {'trainable': '345.25K', 'non_trainable': '0', 'total': '345.25K'}}
# etth_vp_sde_BRIDGE-TS-BEST_gp_rbf_0.5_GAUSSIAN_BETA0.2_10_0.1: start training...
# loss: 17.679605: 100%|████████████████████| 18000/18000 [28:20<00:00,  7.83it/s]
# ============================================================
# ============================================================
#
# loss: 17.679605: 100%|████████████████████| 18000/18000 [28:20<00:00, 10.58it/s]
# training complete loss: 17.679605
# Training done, time: 1700.97
# 2026-02-05 02:38:54.870196: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-05 02:38:54.912353: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.1 beta with 0.2 10.0
# pred with:  vp
# churn ratio 0.33
# {'overall': {'trainable': '345.25K', 'non_trainable': '0', 'total': '345.25K'}, 'model': {'trainable': '345.25K', 'non_trainable': '0', 'total': '345.25K'}}
# Begin to sample...
# Sampling time steps 40
# sampling with NFE: 119
# 1111 torch.Size([2001, 24, 7]) torch.Size([2001, 24, 7])
# 2222 torch.Size([2001, 24, 7]) torch.Size([2001, 24, 7])
# Sampling time steps 40
# sampling with NFE: 119
# 1111 torch.Size([2001, 24, 7]) torch.Size([2001, 24, 7])
# 2222 torch.Size([2001, 24, 7]) torch.Size([2001, 24, 7])
# Sampling time steps 40
# sampling with NFE: 119
# 1111 torch.Size([2001, 24, 7]) torch.Size([2001, 24, 7])
# 2222 torch.Size([2001, 24, 7]) torch.Size([2001, 24, 7])
# Sampling time steps 40
# sampling with NFE: 119
# 1111 torch.Size([2001, 24, 7]) torch.Size([2001, 24, 7])
# 2222 torch.Size([2001, 24, 7]) torch.Size([2001, 24, 7])
# Sampling time steps 40
# sampling with NFE: 119
# 1111 torch.Size([2001, 24, 7]) torch.Size([2001, 24, 7])
# 2222 torch.Size([2001, 24, 7]) torch.Size([2001, 24, 7])
# Sampling time steps 40
# sampling with NFE: 119
# 1111 torch.Size([2001, 24, 7]) torch.Size([2001, 24, 7])
# 2222 torch.Size([2001, 24, 7]) torch.Size([2001, 24, 7])
# Sampling time steps 40
# sampling with NFE: 119
# 1111 torch.Size([2001, 24, 7]) torch.Size([2001, 24, 7])
# 2222 torch.Size([2001, 24, 7]) torch.Size([2001, 24, 7])
# Sampling time steps 40
# sampling with NFE: 119
# 1111 torch.Size([2001, 24, 7]) torch.Size([2001, 24, 7])
# 2222 torch.Size([2001, 24, 7]) torch.Size([2001, 24, 7])
# Sampling time steps 40
# sampling with NFE: 119
# 1111 torch.Size([2001, 24, 7]) torch.Size([2001, 24, 7])
# 2222 torch.Size([2001, 24, 7]) torch.Size([2001, 24, 7])
# Sampling done, time: 43.56, with samples (18009, 24, 7)
# Iter 0
#
# context-fid = 0.08640772480032316
#
# cross-correlation = 0.0438614578455535
#
# WARNING:tensorflow:From /app/Utils/discriminative_metric.py:103: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/src/layers/rnn/legacy_cells.py:585: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/src/layers/rnn/legacy_cells.py:599: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /app/Utils/discriminative_metric.py:107: all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Please use tf.global_variables instead.
# 2026-02-05 02:40:16.260756: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# training: 100%|█████████████████████████████| 2000/2000 [00:37<00:00, 53.70it/s]
# discriminative_score = 0.055603448275862055 with fake/real 0.5310344827586206 0.5801724137931035
#
# training: 100%|█████████████████████████████| 5000/5000 [01:21<00:00, 61.26it/s]
# predictive_score = 0.11370598108150867
#
# Iter 1
#
# context-fid = 0.07677755963355512
#
# cross-correlation = 0.036044879508440285
#
# training: 100%|█████████████████████████████| 2000/2000 [00:37<00:00, 53.60it/s]
# discriminative_score = 0.051005747126436796 with fake/real 0.4870689655172414 0.6149425287356322
#
# training: 100%|█████████████████████████████| 5000/5000 [01:22<00:00, 60.68it/s]
# predictive_score = 0.12058295404238496
#
# Iter 2
#
# context-fid = 0.08428877939138912
#
# cross-correlation = 0.03473776931702068
#
# training: 100%|█████████████████████████████| 2000/2000 [00:37<00:00, 53.48it/s]
# discriminative_score = 0.03663793103448276 with fake/real 0.44166666666666665 0.6316091954022989
#
# training: 100%|█████████████████████████████| 5000/5000 [01:22<00:00, 60.37it/s]
# predictive_score = 0.12709168755394168
#
# Iter 3
#
# context-fid = 0.06971184647083886
#
# cross-correlation = 0.04173061636349392
#
# training: 100%|█████████████████████████████| 2000/2000 [00:37<00:00, 53.87it/s]
# discriminative_score = 0.057040229885057525 with fake/real 0.5114942528735632 0.6025862068965517
#
# training: 100%|█████████████████████████████| 5000/5000 [01:23<00:00, 60.24it/s]
# predictive_score = 0.12251129522751684
#
# Iter 4
#
# context-fid = 0.08189095120437664
#
# cross-correlation = 0.03716113740385425
#
# training: 100%|█████████████████████████████| 2000/2000 [00:37<00:00, 53.69it/s]
# discriminative_score = 0.05287356321839076 with fake/real 0.43448275862068964 0.671264367816092
#
# training: 100%|█████████████████████████████| 5000/5000 [01:22<00:00, 60.62it/s]
# predictive_score = 0.12058345605559276
#
# Context-Fid Final Score:  0.07981537230009658 ± 0.008308208702759041
# Cross-Correlation Final Score:  0.03870717208767253 ± 0.0048465495785076345
# Discriminative Final Score:  0.05063218390804598 ± 0.010140278583475854
# Predictive Final Score:  0.120895074792189 ± 0.005983473429720419
# Traceback (most recent call last):
#   File "main.py", line 342, in <module>
#     main()
#   File "main.py", line 335, in main
#     df.to_csv(args.result_csv, index=False, mode='w', encoding='utf-8-sig')
#   File "/usr/local/lib/python3.8/dist-packages/pandas/core/generic.py", line 3772, in to_csv
#     return DataFrameRenderer(formatter).to_csv(
#   File "/usr/local/lib/python3.8/dist-packages/pandas/io/formats/format.py", line 1186, in to_csv
#     csv_formatter.save()
#   File "/usr/local/lib/python3.8/dist-packages/pandas/io/formats/csvs.py", line 240, in save
#     with get_handle(
#   File "/usr/local/lib/python3.8/dist-packages/pandas/io/common.py", line 737, in get_handle
#     check_parent_directory(str(handle))
#   File "/usr/local/lib/python3.8/dist-packages/pandas/io/common.py", line 600, in check_parent_directory
#     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
# OSError: Cannot save file into a non-existent directory: 'results'
# (0.1, 2, 0.5, 0.1) fmri
# 2026-02-05 02:52:53.841385: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-05 02:52:53.872042: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.5 beta with 0.1 2.0
# pred with:  vp
# churn ratio 0.33
# {'overall': {'trainable': '1.34M', 'non_trainable': '0', 'total': '1.34M'}, 'model': {'trainable': '1.34M', 'non_trainable': '0', 'total': '1.34M'}}
# fmri_vp_sde_BRIDGE-TS-BEST_gp_rbf_0.1_GAUSSIAN_BETA0.1_2_0.5: start training...
# loss: 3.210729: 100%|█████████████████████| 15000/15000 [29:02<00:00,  6.68it/s]
# ============================================================
# ============================================================
#
# loss: 3.210729: 100%|█████████████████████| 15000/15000 [29:02<00:00,  8.61it/s]
# training complete loss: 3.210729
# Training done, time: 1742.94
# 2026-02-05 03:22:03.653576: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-05 03:22:03.684463: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.5 beta with 0.1 2.0
# pred with:  vp
# churn ratio 0.33
# {'overall': {'trainable': '1.34M', 'non_trainable': '0', 'total': '1.34M'}, 'model': {'trainable': '1.34M', 'non_trainable': '0', 'total': '1.34M'}}
# Begin to sample...
# Sampling time steps 40
# sampling with NFE: 119
# 1111 torch.Size([2001, 24, 50]) torch.Size([2001, 24, 50])
# 2222 torch.Size([2001, 24, 50]) torch.Size([2001, 24, 50])
# Sampling time steps 40
# sampling with NFE: 119
# 1111 torch.Size([2001, 24, 50]) torch.Size([2001, 24, 50])
# 2222 torch.Size([2001, 24, 50]) torch.Size([2001, 24, 50])
# Sampling time steps 40
# sampling with NFE: 119
# 1111 torch.Size([2001, 24, 50]) torch.Size([2001, 24, 50])
# 2222 torch.Size([2001, 24, 50]) torch.Size([2001, 24, 50])
# Sampling time steps 40
# sampling with NFE: 119
# 1111 torch.Size([2001, 24, 50]) torch.Size([2001, 24, 50])
# 2222 torch.Size([2001, 24, 50]) torch.Size([2001, 24, 50])
# Sampling time steps 40
# sampling with NFE: 119
# 1111 torch.Size([2001, 24, 50]) torch.Size([2001, 24, 50])
# 2222 torch.Size([2001, 24, 50]) torch.Size([2001, 24, 50])
# Sampling done, time: 34.22, with samples (10005, 24, 50)
# Iter 0
#
# context-fid = 0.09201053506197993
#
# cross-correlation = 0.8377231093678738
#
# WARNING:tensorflow:From /app/Utils/discriminative_metric.py:103: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/src/layers/rnn/legacy_cells.py:585: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/src/layers/rnn/legacy_cells.py:599: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /app/Utils/discriminative_metric.py:107: all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Please use tf.global_variables instead.
# 2026-02-05 03:23:10.523575: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# training: 100%|█████████████████████████████| 2000/2000 [00:44<00:00, 44.45it/s]
# discriminative_score = 0.07865731462925851 with fake/real 0.5596192384769539 0.5976953907815631
#
# training: 100%|█████████████████████████████| 5000/5000 [01:51<00:00, 44.71it/s]
# predictive_score = 0.09984387516536448
#
# Iter 1
#
# context-fid = 0.09691306126725505
#
# cross-correlation = 0.8096009157003975
#
# training: 100%|█████████████████████████████| 2000/2000 [00:44<00:00, 44.64it/s]
# discriminative_score = 0.1019539078156313 with fake/real 0.7079158316633266 0.49599198396793587
#
# training: 100%|█████████████████████████████| 5000/5000 [01:54<00:00, 43.75it/s]
# predictive_score = 0.1002239246369952
#
# Iter 2
#
# context-fid = 0.10759460170539889
#
# cross-correlation = 0.8340726254021531
#
# training: 100%|█████████████████████████████| 2000/2000 [00:44<00:00, 44.59it/s]
# discriminative_score = 0.08141282565130259 with fake/real 0.814128256513026 0.3486973947895792
#
# training: 100%|█████████████████████████████| 5000/5000 [01:53<00:00, 44.17it/s]
# predictive_score = 0.09986089102043037
#
# Iter 3
#
# context-fid = 0.09248180266316935
#
# cross-correlation = 0.8257770923625414
#
# training: 100%|█████████████████████████████| 2000/2000 [00:44<00:00, 44.78it/s]
# discriminative_score = 0.09168336673346689 with fake/real 0.7449899799599199 0.43837675350701405
#
# training: 100%|█████████████████████████████| 5000/5000 [01:50<00:00, 45.19it/s]
# predictive_score = 0.0997869943504817
#
# Iter 4
#
# context-fid = 0.09367534312336838
#
# cross-correlation = 0.8468915229294331
#
# training: 100%|█████████████████████████████| 2000/2000 [00:43<00:00, 45.69it/s]
# discriminative_score = 0.09869739478957917 with fake/real 0.7374749498997996 0.45991983967935873
#
# training: 100%|█████████████████████████████| 5000/5000 [01:52<00:00, 44.62it/s]
# predictive_score = 0.09980677242242511
#
# Context-Fid Final Score:  0.09653506876423432 ± 0.008035747542296696
# Cross-Correlation Final Score:  0.8308130531524798 ± 0.017474039340018434
# Discriminative Final Score:  0.09048096192384769 ± 0.012762798492270614
# Predictive Final Score:  0.09990449151913938 ± 0.0002246755486505188
# Traceback (most recent call last):
#   File "main.py", line 342, in <module>
#     main()
#   File "main.py", line 335, in main
#     df.to_csv(args.result_csv, index=False, mode='w', encoding='utf-8-sig')
#   File "/usr/local/lib/python3.8/dist-packages/pandas/core/generic.py", line 3772, in to_csv
#     return DataFrameRenderer(formatter).to_csv(
#   File "/usr/local/lib/python3.8/dist-packages/pandas/io/formats/format.py", line 1186, in to_csv
#     csv_formatter.save()
#   File "/usr/local/lib/python3.8/dist-packages/pandas/io/formats/csvs.py", line 240, in save
#     with get_handle(
#   File "/usr/local/lib/python3.8/dist-packages/pandas/io/common.py", line 737, in get_handle
#     check_parent_directory(str(handle))
#   File "/usr/local/lib/python3.8/dist-packages/pandas/io/common.py", line 600, in check_parent_directory
#     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
# OSError: Cannot save file into a non-existent directory: 'results'
# (0.1, 5, 0.5, 0.1) mujoco
# 2026-02-05 03:38:46.510180: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-05 03:38:46.541482: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.5 beta with 0.1 5.0
# pred with:  vp
# churn ratio 0.33
# {'overall': {'trainable': '351.84K', 'non_trainable': '0', 'total': '351.84K'}, 'model': {'trainable': '351.84K', 'non_trainable': '0', 'total': '351.84K'}}
# mujoco_vp_sde_BRIDGE-TS-BEST_gp_rbf_0.1_GAUSSIAN_BETA0.1_5_0.5: start training...
# loss: 0.831834: 100%|█████████████████████| 14000/14000 [18:59<00:00, 12.94it/s]
# ============================================================
# ============================================================
#
# loss: 0.831834: 100%|█████████████████████| 14000/14000 [18:59<00:00, 12.28it/s]
# training complete loss: 0.831834
# Training done, time: 1139.96
# 2026-02-05 03:57:57.951928: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-05 03:57:57.983014: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.5 beta with 0.1 5.0
# pred with:  vp
# churn ratio 0.33
# {'overall': {'trainable': '351.84K', 'non_trainable': '0', 'total': '351.84K'}, 'model': {'trainable': '351.84K', 'non_trainable': '0', 'total': '351.84K'}}
# Begin to sample...
# Sampling time steps 40
# sampling with NFE: 119
# 1111 torch.Size([2001, 24, 14]) torch.Size([2001, 24, 14])
# 2222 torch.Size([2001, 24, 14]) torch.Size([2001, 24, 14])
# Sampling time steps 40
# sampling with NFE: 119
# 1111 torch.Size([2001, 24, 14]) torch.Size([2001, 24, 14])
# 2222 torch.Size([2001, 24, 14]) torch.Size([2001, 24, 14])
# Sampling time steps 40
# sampling with NFE: 119
# 1111 torch.Size([2001, 24, 14]) torch.Size([2001, 24, 14])
# 2222 torch.Size([2001, 24, 14]) torch.Size([2001, 24, 14])
# Sampling time steps 40
# sampling with NFE: 119
# 1111 torch.Size([2001, 24, 14]) torch.Size([2001, 24, 14])
# 2222 torch.Size([2001, 24, 14]) torch.Size([2001, 24, 14])
# Sampling time steps 40
# sampling with NFE: 119
# 1111 torch.Size([2001, 24, 14]) torch.Size([2001, 24, 14])
# 2222 torch.Size([2001, 24, 14]) torch.Size([2001, 24, 14])
# Sampling done, time: 15.25, with samples (10005, 24, 14)
# Iter 0
#
# context-fid = 0.01833248913917474
#
# cross-correlation = 0.18956505132592388
#
# WARNING:tensorflow:From /app/Utils/discriminative_metric.py:103: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /app/Utils/discriminative_metric.py:103: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/src/layers/rnn/legacy_cells.py:585: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/src/layers/rnn/legacy_cells.py:585: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/src/layers/rnn/legacy_cells.py:599: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/src/layers/rnn/legacy_cells.py:599: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /app/Utils/discriminative_metric.py:107: all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Please use tf.global_variables instead.
# WARNING:tensorflow:From /app/Utils/discriminative_metric.py:107: all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Please use tf.global_variables instead.
# 2026-02-05 03:58:49.696152: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# training: 100%|█████████████████████████████| 2000/2000 [00:34<00:00, 57.45it/s]
# discriminative_score = 0.005249999999999977 with fake/real 0.5105 0.5
#
# training: 100%|█████████████████████████████| 5000/5000 [01:25<00:00, 58.75it/s]
# predictive_score = 0.008584771583200267
#
# Iter 1
#
# context-fid = 0.016192607362457916
#
# cross-correlation = 0.15580885363518263
#
# training: 100%|█████████████████████████████| 2000/2000 [00:36<00:00, 55.39it/s]
# discriminative_score = 0.006249999999999978 with fake/real 0.5205 0.492
#
# training: 100%|█████████████████████████████| 5000/5000 [01:26<00:00, 58.03it/s]
# predictive_score = 0.008429124985014445
#
# Iter 2
#
# context-fid = 0.019438594220155325
#
# cross-correlation = 0.20378108091218655
#
# training: 100%|█████████████████████████████| 2000/2000 [00:35<00:00, 56.11it/s]
# discriminative_score = 0.023499999999999965 with fake/real 0.5625 0.4845
#
# training: 100%|█████████████████████████████| 5000/5000 [01:25<00:00, 58.82it/s]
# predictive_score = 0.009777613144811573
#
# Iter 3
#
# context-fid = 0.017996308792938565
#
# cross-correlation = 0.15807232362313905
#
# training: 100%|█████████████████████████████| 2000/2000 [00:35<00:00, 56.90it/s]
# discriminative_score = 0.010249999999999981 with fake/real 0.576 0.4445
#
# training: 100%|█████████████████████████████| 5000/5000 [01:26<00:00, 58.02it/s]
# predictive_score = 0.008410500200626937
#
# Iter 4
#
# context-fid = 0.014611397145559805
#
# cross-correlation = 0.16937086647246283
#
# training: 100%|█████████████████████████████| 2000/2000 [00:36<00:00, 55.26it/s]
# discriminative_score = 0.02400000000000002 with fake/real 0.5225 0.5255
#
# training: 100%|█████████████████████████████| 5000/5000 [01:25<00:00, 58.72it/s]
# predictive_score = 0.008475242418544174
#
# Context-Fid Final Score:  0.01731427933205727 ± 0.0023704361883287277
# Cross-Correlation Final Score:  0.175319635193779 ± 0.025796402374832845
# Discriminative Final Score:  0.013849999999999984 ± 0.011461456621353627
# Predictive Final Score:  0.00873545046643948 ± 0.0007282397398632821
# Traceback (most recent call last):
#   File "main.py", line 342, in <module>
#     main()
#   File "main.py", line 335, in main
#     df.to_csv(args.result_csv, index=False, mode='w', encoding='utf-8-sig')
#   File "/usr/local/lib/python3.8/dist-packages/pandas/core/generic.py", line 3772, in to_csv
#     return DataFrameRenderer(formatter).to_csv(
#   File "/usr/local/lib/python3.8/dist-packages/pandas/io/formats/format.py", line 1186, in to_csv
#     csv_formatter.save()
#   File "/usr/local/lib/python3.8/dist-packages/pandas/io/formats/csvs.py", line 240, in save
#     with get_handle(
#   File "/usr/local/lib/python3.8/dist-packages/pandas/io/common.py", line 737, in get_handle
#     check_parent_directory(str(handle))
#   File "/usr/local/lib/python3.8/dist-packages/pandas/io/common.py", line 600, in check_parent_directory
#     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
# OSError: Cannot save file into a non-existent directory: 'results'
# (0.2, 10, 0.5, 1) sines
# 2026-02-05 04:11:11.554750: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-05 04:11:11.585139: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.5 beta with 0.2 10.0
# pred with:  vp
# churn ratio 0.33
# Sampling sine-dataset: 100%|████████████| 10000/10000 [00:01<00:00, 9387.92it/s]
# {'overall': {'trainable': '229.74K', 'non_trainable': '0', 'total': '229.74K'}, 'model': {'trainable': '229.74K', 'non_trainable': '0', 'total': '229.74K'}}
# sines_vp_sde_BRIDGE-TS-BEST_gp_rbf_1_GAUSSIAN_BETA0.2_10_0.5: start training...
# loss: 0.963130: 100%|████████████████████▉| 11999/12000 [13:40<00:00, 12.96it/s]
# ============================================================
# ============================================================
#
# loss: 0.963130: 100%|█████████████████████| 12000/12000 [13:40<00:00, 14.62it/s]
# training complete loss: 0.963130
# Training done, time: 820.96
# 2026-02-05 04:24:59.964043: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-05 04:24:59.995281: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.5 beta with 0.2 10.0
# pred with:  vp
# churn ratio 0.33
# Sampling sine-dataset: 100%|████████████| 10000/10000 [00:01<00:00, 9294.85it/s]
# {'overall': {'trainable': '229.74K', 'non_trainable': '0', 'total': '229.74K'}, 'model': {'trainable': '229.74K', 'non_trainable': '0', 'total': '229.74K'}}
# Begin to sample...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling done, time: 13.57, with samples (10005, 24, 5)
# Iter 0
#
# context-fid = 0.006612314216150555
#
# cross-correlation = 0.017449879486952907
#
# WARNING:tensorflow:From /app/Utils/discriminative_metric.py:103: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/src/layers/rnn/legacy_cells.py:585: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/src/layers/rnn/legacy_cells.py:599: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /app/Utils/discriminative_metric.py:107: all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Please use tf.global_variables instead.
# 2026-02-05 04:25:45.955512: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# training: 100%|█████████████████████████████| 2000/2000 [00:35<00:00, 56.67it/s]
# discriminative_score = 0.0020000000000000018 with fake/real 0.42 0.584
#
# training: 100%|█████████████████████████████| 5000/5000 [01:20<00:00, 62.25it/s]
# predictive_score = 0.09305942262172766
#
# Iter 1
#
# context-fid = 0.008148217624769853
#
# cross-correlation = 0.025418879977106363
#
# training: 100%|█████████████████████████████| 2000/2000 [00:35<00:00, 56.10it/s]
# discriminative_score = 0.009750000000000036 with fake/real 0.4685 0.551
#
# training: 100%|█████████████████████████████| 5000/5000 [01:20<00:00, 62.20it/s]
# predictive_score = 0.09304112590897631
#
# Iter 2
#
# context-fid = 0.010585517889017647
#
# cross-correlation = 0.017558205192366245
#
# training: 100%|█████████████████████████████| 2000/2000 [00:35<00:00, 56.54it/s]
# discriminative_score = 0.007249999999999979 with fake/real 0.3845 0.63
#
# training: 100%|█████████████████████████████| 5000/5000 [01:18<00:00, 63.65it/s]
# predictive_score = 0.09317893994154577
#
# Iter 3
#
# context-fid = 0.008208001644023617
#
# cross-correlation = 0.016935567914646493
#
# training: 100%|█████████████████████████████| 2000/2000 [00:32<00:00, 61.96it/s]
# discriminative_score = 0.00649999999999995 with fake/real 0.4155 0.5975
#
# training: 100%|█████████████████████████████| 5000/5000 [01:13<00:00, 68.16it/s]
# predictive_score = 0.09293316099867029
#
# Iter 4
#
# context-fid = 0.00770562425917499
#
# cross-correlation = 0.01537726874336432
#
# training: 100%|█████████████████████████████| 2000/2000 [00:31<00:00, 62.66it/s]
# discriminative_score = 0.0047499999999999765 with fake/real 0.4625 0.528
#
# training: 100%|█████████████████████████████| 5000/5000 [01:13<00:00, 68.03it/s]
# predictive_score = 0.09285831508954319
#
# Context-Fid Final Score:  0.008251935126627332 ± 0.0018041668731885307
# Cross-Correlation Final Score:  0.018547960262887263 ± 0.004890329084731819
# Discriminative Final Score:  0.0060499999999999885 ± 0.003589300350251158
# Predictive Final Score:  0.09301419291209263 ± 0.00015305336310508978
# Traceback (most recent call last):
#   File "main.py", line 344, in <module>
#   File "main.py", line 337, in main
#     df.to_csv(args.result_csv, index=False, mode='a', encoding='utf-8-sig', header=False)
#   File "/usr/local/lib/python3.8/dist-packages/pandas/core/generic.py", line 3772, in to_csv
#     return DataFrameRenderer(formatter).to_csv(
#   File "/usr/local/lib/python3.8/dist-packages/pandas/io/formats/format.py", line 1186, in to_csv
#     csv_formatter.save()
#   File "/usr/local/lib/python3.8/dist-packages/pandas/io/formats/csvs.py", line 240, in save
#     with get_handle(
#   File "/usr/local/lib/python3.8/dist-packages/pandas/io/common.py", line 737, in get_handle
#     check_parent_directory(str(handle))
#   File "/usr/local/lib/python3.8/dist-packages/pandas/io/common.py", line 600, in check_parent_directory
#     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
# OSError: Cannot save file into a non-existent directory: 'results'
# (0.2, 10, 0.1, 0.3) stock
# 2026-02-05 04:37:19.809760: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-05 04:37:19.848371: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.1 beta with 0.2 10.0
# pred with:  vp
# churn ratio 0.33
# {'overall': {'trainable': '287.49K', 'non_trainable': '0', 'total': '287.49K'}, 'model': {'trainable': '287.49K', 'non_trainable': '0', 'total': '287.49K'}}
# stock_vp_sde_BRIDGE-TS-BEST_gp_rbf_0.3_GAUSSIAN_BETA0.2_10_0.1: start training...
# loss: 14.608638: 100%|████████████████████▉| 9999/10000 [12:04<00:00, 14.20it/s]
# ============================================================
# ============================================================
#
# loss: 14.608638: 100%|████████████████████| 10000/10000 [12:04<00:00, 13.81it/s]
# training complete loss: 14.608638
# Training done, time: 724.33
# 2026-02-05 04:49:30.960241: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-05 04:49:30.991676: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.1 beta with 0.2 10.0
# pred with:  vp
# churn ratio 0.33
# {'overall': {'trainable': '287.49K', 'non_trainable': '0', 'total': '287.49K'}, 'model': {'trainable': '287.49K', 'non_trainable': '0', 'total': '287.49K'}}
# Begin to sample...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling done, time: 6.15, with samples (4002, 24, 6)
# Iter 0
#
# context-fid = 0.10564521601413605
#
# cross-correlation = 0.02037682778499116
#
# WARNING:tensorflow:From /app/Utils/discriminative_metric.py:103: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/src/layers/rnn/legacy_cells.py:585: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/src/layers/rnn/legacy_cells.py:599: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /app/Utils/discriminative_metric.py:107: all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Please use tf.global_variables instead.
# 2026-02-05 04:50:04.402097: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# training: 100%|█████████████████████████████| 2000/2000 [00:31<00:00, 64.33it/s]
# discriminative_score = 0.02660300136425653 with fake/real 0.6616643929058663 0.39154160982264663
#
# training: 100%|█████████████████████████████| 5000/5000 [01:12<00:00, 69.06it/s]
# predictive_score = 0.03726208452130651
#
# Iter 1
#
# context-fid = 0.09547230642506344
#
# cross-correlation = 0.01667807050872705
#
# training: 100%|█████████████████████████████| 2000/2000 [00:30<00:00, 64.79it/s]
# discriminative_score = 0.07025920873124147 with fake/real 0.39290586630286495 0.747612551159618
#
# training: 100%|█████████████████████████████| 5000/5000 [01:10<00:00, 70.59it/s]
# predictive_score = 0.0374970548240458
#
# Iter 2
#
# context-fid = 0.06869057388129776
#
# cross-correlation = 0.027083905049495482
#
# training: 100%|█████████████████████████████| 2000/2000 [00:30<00:00, 64.92it/s]
# discriminative_score = 0.030013642564802212 with fake/real 0.6521145975443383 0.40791268758526605
#
# training: 100%|█████████████████████████████| 5000/5000 [01:11<00:00, 69.46it/s]
# predictive_score = 0.03728440905314759
#
# Iter 3
#
# context-fid = 0.11768220665829239
#
# cross-correlation = 0.014036895368813963
#
# training: 100%|█████████████████████████████| 2000/2000 [00:31<00:00, 64.49it/s]
# discriminative_score = 0.049113233287858105 with fake/real 0.4392905866302865 0.6589358799454298
#
# training: 100%|█████████████████████████████| 5000/5000 [01:10<00:00, 70.58it/s]
# predictive_score = 0.03750600978336074
#
# Iter 4
#
# context-fid = 0.08997384245910545
#
# cross-correlation = 0.014399018232639338
#
# training: 100%|█████████████████████████████| 2000/2000 [00:31<00:00, 64.21it/s]
# discriminative_score = 0.04160982264665758 with fake/real 0.4488403819918145 0.6343792633015006
#
# training: 100%|█████████████████████████████| 5000/5000 [01:10<00:00, 70.49it/s]
# predictive_score = 0.03736161659486255
#
# Context-Fid Final Score:  0.09549282908757903 ± 0.02276227805452512
# Cross-Correlation Final Score:  0.0185149433889334 ± 0.006722827252712675
# Discriminative Final Score:  0.04351978171896318 ± 0.021671615618841907
# Predictive Final Score:  0.03738223495534464 ± 0.00014283853661962173
# Traceback (most recent call last):
#   File "main.py", line 342, in <module>
#     main()
#   File "main.py", line 335, in main
#     df.to_csv(args.result_csv, index=False, mode='w', encoding='utf-8-sig')
#   File "/usr/local/lib/python3.8/dist-packages/pandas/core/generic.py", line 3772, in to_csv
#     return DataFrameRenderer(formatter).to_csv(
#   File "/usr/local/lib/python3.8/dist-packages/pandas/io/formats/format.py", line 1186, in to_csv
#     csv_formatter.save()
#   File "/usr/local/lib/python3.8/dist-packages/pandas/io/formats/csvs.py", line 240, in save
#     with get_handle(
#   File "/usr/local/lib/python3.8/dist-packages/pandas/io/common.py", line 737, in get_handle
#     check_parent_directory(str(handle))
#   File "/usr/local/lib/python3.8/dist-packages/pandas/io/common.py", line 600, in check_parent_directory
#     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
# OSError: Cannot save file into a non-existent directory: 'results'
# Trained with stock_vp_sde_BRIDGE-TS-BEST_gp_rbf_0.3_GAUSSIAN_BETA0.2_10_0.1
# ********************
