# %%
import os
import warnings

warnings.filterwarnings("ignore")
if 'run' in os.getcwd():
    os.chdir('..')
    
os.environ["CUDA_VISIBLE_DEVICES"] = "0" # Possible GPUS

# %%
SAMPLE = 0 # unconditional
MODE = "generation"
NAME = 'SIGMA_MIN_1e-4'
PRED_MODE = 'vp'
SAMPLER = 'sde'
SIGMA_MIN = 0.0001
SIGMA_MAX = 1
KERNEL_TYPE= 'rbf'
RESULT = "./results/result_best_gp.csv"

# %%
best_hyperparams = {}

# %%
#BETA_MIN, BETA_MAX, SIGMA_DATA, VAR
best_hyperparams['energy'] = (0.2, 10, 0.05, 1)
best_hyperparams['etth'] = (0.2, 10, 0.1, 0.5)
best_hyperparams['fmri'] = (0.1, 2, 0.5,  0.1)
best_hyperparams['mujoco'] = (0.1, 5, 0.5, 0.1)
best_hyperparams['sines'] = (0.2, 10, 0.5, 1)
best_hyperparams['stock'] = (0.2, 10, 0.1,  0.3)

# %%
NAME = 'BRIDGE-TS-BEST'
PRIOR = 'gp'
BW = 'GAUSSIAN'

# for DATA in ['energy', 'etth', 'fmri', 'mujoco', 'sines', 'stock']:
# BETA_MIN, BETA_MAX, SIGMA_DATA, VAR = best_hyperparams[DATA]
# print(best_hyperparams[DATA], DATA)

# NAME_ = DATA + "_" + PRED_MODE + "_" + SAMPLER + "_" + NAME + "_" + PRIOR + "_" + KERNEL_TYPE + "_" + str(VAR) + "_" +  BW + "_BETA" + str(BETA_MIN) + "_" + str(BETA_MAX)+"_"+ str(SIGMA_DATA) 

# !python main.py --data {DATA} --name {NAME_} --sample {SAMPLE} --mode {MODE} --train --pred_mode {PRED_MODE} --sampler {SAMPLER} --prior {PRIOR} \
# --sigma_min {SIGMA_MIN} --sigma_max {SIGMA_MAX} --sigma_data {SIGMA_DATA} --beta_min {BETA_MIN} --beta_d {BETA_MAX}  --result_csv {RESULT} --model_matching "D_matching" \
# --kernel_type {KERNEL_TYPE} --bw {BW} --var {VAR}

# !python main.py --data {DATA} --name {NAME_} --sample {SAMPLE} --mode {MODE} --eval --pred_mode {PRED_MODE} --sampler {SAMPLER} --prior {PRIOR} \
# --sigma_min {SIGMA_MIN} --sigma_max {SIGMA_MAX} --sigma_data {SIGMA_DATA} --beta_min {BETA_MIN} --beta_d {BETA_MAX}  --result_csv {RESULT} --model_matching "D_matching" \
# --kernel_type {KERNEL_TYPE} --bw {BW} --var {VAR}
     
# print(f'Trained with {NAME_}')
# print('*'*20)

# %%
DATA = 'energy'
BETA_MIN, BETA_MAX, SIGMA_DATA, VAR = best_hyperparams[DATA]
print(best_hyperparams[DATA], DATA)

NAME_ = DATA + "_" + PRED_MODE + "_" + SAMPLER + "_" + NAME + "_" + PRIOR + "_" + KERNEL_TYPE + "_" + str(VAR) + "_" +  BW + "_BETA" + str(BETA_MIN) + "_" + str(BETA_MAX)+"_"+ str(SIGMA_DATA) 

# !python main.py --data {DATA} --name {NAME_} --sample {SAMPLE} --mode {MODE} --train --pred_mode {PRED_MODE} --sampler {SAMPLER} --prior {PRIOR} \
--sigma_min {SIGMA_MIN} --sigma_max {SIGMA_MAX} --sigma_data {SIGMA_DATA} --beta_min {BETA_MIN} --beta_d {BETA_MAX}  --result_csv {RESULT} --model_matching "D_matching" \
--kernel_type {KERNEL_TYPE} --bw {BW} --var {VAR}

# !python main.py --data {DATA} --name {NAME_} --sample {SAMPLE} --mode {MODE} --eval --pred_mode {PRED_MODE} --sampler {SAMPLER} --prior {PRIOR} \
--sigma_min {SIGMA_MIN} --sigma_max {SIGMA_MAX} --sigma_data {SIGMA_DATA} --beta_min {BETA_MIN} --beta_d {BETA_MAX}  --result_csv {RESULT} --model_matching "D_matching" \
--kernel_type {KERNEL_TYPE} --bw {BW} --var {VAR}
     
print(f'Trained with {NAME_}')
print('*'*20)
# Out:
# (0.2, 10, 0.05, 1) energy
# 2026-02-06 02:10:41.008170: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-06 02:10:41.039080: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.05 beta with 0.2 10.0
# pred with:  vp
# churn ratio 0.33
# {'overall': {'trainable': '1.09M', 'non_trainable': '0', 'total': '1.09M'}, 'model': {'trainable': '1.09M', 'non_trainable': '0', 'total': '1.09M'}}
# ...

# %%
DATA = 'etth'
BETA_MIN, BETA_MAX, SIGMA_DATA, VAR = best_hyperparams[DATA]
print(best_hyperparams[DATA], DATA)

NAME_ = DATA + "_" + PRED_MODE + "_" + SAMPLER + "_" + NAME + "_" + PRIOR + "_" + KERNEL_TYPE + "_" + str(VAR) + "_" +  BW + "_BETA" + str(BETA_MIN) + "_" + str(BETA_MAX)+"_"+ str(SIGMA_DATA) 

# !python main.py --data {DATA} --name {NAME_} --sample {SAMPLE} --mode {MODE} --train --pred_mode {PRED_MODE} --sampler {SAMPLER} --prior {PRIOR} \
--sigma_min {SIGMA_MIN} --sigma_max {SIGMA_MAX} --sigma_data {SIGMA_DATA} --beta_min {BETA_MIN} --beta_d {BETA_MAX}  --result_csv {RESULT} --model_matching "D_matching" \
--kernel_type {KERNEL_TYPE} --bw {BW} --var {VAR}

# !python main.py --data {DATA} --name {NAME_} --sample {SAMPLE} --mode {MODE} --eval --pred_mode {PRED_MODE} --sampler {SAMPLER} --prior {PRIOR} \
--sigma_min {SIGMA_MIN} --sigma_max {SIGMA_MAX} --sigma_data {SIGMA_DATA} --beta_min {BETA_MIN} --beta_d {BETA_MAX}  --result_csv {RESULT} --model_matching "D_matching" \
--kernel_type {KERNEL_TYPE} --bw {BW} --var {VAR}
     
print(f'Trained with {NAME_}')
print('*'*20)
# Out:
# (0.2, 10, 0.1, 0.5) etth
# 2026-02-06 03:04:55.127095: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-06 03:04:55.158023: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.1 beta with 0.2 10.0
# pred with:  vp
# churn ratio 0.33
# {'overall': {'trainable': '345.25K', 'non_trainable': '0', 'total': '345.25K'}, 'model': {'trainable': '345.25K', 'non_trainable': '0', 'total': '345.25K'}}
# ...

# %%
DATA = 'fmri'
BETA_MIN, BETA_MAX, SIGMA_DATA, VAR = best_hyperparams[DATA]
print(best_hyperparams[DATA], DATA)

NAME_ = DATA + "_" + PRED_MODE + "_" + SAMPLER + "_" + NAME + "_" + PRIOR + "_" + KERNEL_TYPE + "_" + str(VAR) + "_" +  BW + "_BETA" + str(BETA_MIN) + "_" + str(BETA_MAX)+"_"+ str(SIGMA_DATA) 

# !python main.py --data {DATA} --name {NAME_} --sample {SAMPLE} --mode {MODE} --train --pred_mode {PRED_MODE} --sampler {SAMPLER} --prior {PRIOR} \
--sigma_min {SIGMA_MIN} --sigma_max {SIGMA_MAX} --sigma_data {SIGMA_DATA} --beta_min {BETA_MIN} --beta_d {BETA_MAX}  --result_csv {RESULT} --model_matching "D_matching" \
--kernel_type {KERNEL_TYPE} --bw {BW} --var {VAR}

# !python main.py --data {DATA} --name {NAME_} --sample {SAMPLE} --mode {MODE} --eval --pred_mode {PRED_MODE} --sampler {SAMPLER} --prior {PRIOR} \
--sigma_min {SIGMA_MIN} --sigma_max {SIGMA_MAX} --sigma_data {SIGMA_DATA} --beta_min {BETA_MIN} --beta_d {BETA_MAX}  --result_csv {RESULT} --model_matching "D_matching" \
--kernel_type {KERNEL_TYPE} --bw {BW} --var {VAR}
     
print(f'Trained with {NAME_}')
print('*'*20)
# Out:
# (0.1, 2, 0.5, 0.1) fmri
# 2026-02-06 03:41:41.718098: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-06 03:41:41.748931: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.5 beta with 0.1 2.0
# pred with:  vp
# churn ratio 0.33
# {'overall': {'trainable': '1.34M', 'non_trainable': '0', 'total': '1.34M'}, 'model': {'trainable': '1.34M', 'non_trainable': '0', 'total': '1.34M'}}
# ...

# %%
DATA = 'mujoco'
BETA_MIN, BETA_MAX, SIGMA_DATA, VAR = best_hyperparams[DATA]
print(best_hyperparams[DATA], DATA)

NAME_ = DATA + "_" + PRED_MODE + "_" + SAMPLER + "_" + NAME + "_" + PRIOR + "_" + KERNEL_TYPE + "_" + str(VAR) + "_" +  BW + "_BETA" + str(BETA_MIN) + "_" + str(BETA_MAX)+"_"+ str(SIGMA_DATA) 

# !python main.py --data {DATA} --name {NAME_} --sample {SAMPLE} --mode {MODE} --train --pred_mode {PRED_MODE} --sampler {SAMPLER} --prior {PRIOR} \
--sigma_min {SIGMA_MIN} --sigma_max {SIGMA_MAX} --sigma_data {SIGMA_DATA} --beta_min {BETA_MIN} --beta_d {BETA_MAX}  --result_csv {RESULT} --model_matching "D_matching" \
--kernel_type {KERNEL_TYPE} --bw {BW} --var {VAR}

# !python main.py --data {DATA} --name {NAME_} --sample {SAMPLE} --mode {MODE} --eval --pred_mode {PRED_MODE} --sampler {SAMPLER} --prior {PRIOR} \
--sigma_min {SIGMA_MIN} --sigma_max {SIGMA_MAX} --sigma_data {SIGMA_DATA} --beta_min {BETA_MIN} --beta_d {BETA_MAX}  --result_csv {RESULT} --model_matching "D_matching" \
--kernel_type {KERNEL_TYPE} --bw {BW} --var {VAR}
     
print(f'Trained with {NAME_}')
print('*'*20)
# Out:
# (0.1, 5, 0.5, 0.1) mujoco
# 2026-02-06 04:26:41.119931: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-06 04:26:41.160394: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.5 beta with 0.1 5.0
# pred with:  vp
# churn ratio 0.33
# {'overall': {'trainable': '351.84K', 'non_trainable': '0', 'total': '351.84K'}, 'model': {'trainable': '351.84K', 'non_trainable': '0', 'total': '351.84K'}}
# ...

# %%
DATA = 'sines'
BETA_MIN, BETA_MAX, SIGMA_DATA, VAR = best_hyperparams[DATA]
print(best_hyperparams[DATA], DATA)

NAME_ = DATA + "_" + PRED_MODE + "_" + SAMPLER + "_" + NAME + "_" + PRIOR + "_" + KERNEL_TYPE + "_" + str(VAR) + "_" +  BW + "_BETA" + str(BETA_MIN) + "_" + str(BETA_MAX)+"_"+ str(SIGMA_DATA) 

# !python main.py --data {DATA} --name {NAME_} --sample {SAMPLE} --mode {MODE} --train --pred_mode {PRED_MODE} --sampler {SAMPLER} --prior {PRIOR} \
--sigma_min {SIGMA_MIN} --sigma_max {SIGMA_MAX} --sigma_data {SIGMA_DATA} --beta_min {BETA_MIN} --beta_d {BETA_MAX}  --result_csv {RESULT} --model_matching "D_matching" \
--kernel_type {KERNEL_TYPE} --bw {BW} --var {VAR}

# !python main.py --data {DATA} --name {NAME_} --sample {SAMPLE} --mode {MODE} --eval --pred_mode {PRED_MODE} --sampler {SAMPLER} --prior {PRIOR} \
--sigma_min {SIGMA_MIN} --sigma_max {SIGMA_MAX} --sigma_data {SIGMA_DATA} --beta_min {BETA_MIN} --beta_d {BETA_MAX}  --result_csv {RESULT} --model_matching "D_matching" \
--kernel_type {KERNEL_TYPE} --bw {BW} --var {VAR}
     
print(f'Trained with {NAME_}')
print('*'*20)
# Out:
# (0.2, 10, 0.5, 1) sines
# 2026-02-06 04:57:02.762734: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-06 04:57:02.793568: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.5 beta with 0.2 10.0
# pred with:  vp
# churn ratio 0.33
# Sampling sine-dataset: 100%|████████████| 10000/10000 [00:01<00:00, 9557.39it/s]
# ...

# %%
DATA = 'stock'
BETA_MIN, BETA_MAX, SIGMA_DATA, VAR = best_hyperparams[DATA]
print(best_hyperparams[DATA], DATA)

NAME_ = DATA + "_" + PRED_MODE + "_" + SAMPLER + "_" + NAME + "_" + PRIOR + "_" + KERNEL_TYPE + "_" + str(VAR) + "_" +  BW + "_BETA" + str(BETA_MIN) + "_" + str(BETA_MAX)+"_"+ str(SIGMA_DATA) 

# !python main.py --data {DATA} --name {NAME_} --sample {SAMPLE} --mode {MODE} --train --pred_mode {PRED_MODE} --sampler {SAMPLER} --prior {PRIOR} \
--sigma_min {SIGMA_MIN} --sigma_max {SIGMA_MAX} --sigma_data {SIGMA_DATA} --beta_min {BETA_MIN} --beta_d {BETA_MAX}  --result_csv {RESULT} --model_matching "D_matching" \
--kernel_type {KERNEL_TYPE} --bw {BW} --var {VAR}

# !python main.py --data {DATA} --name {NAME_} --sample {SAMPLE} --mode {MODE} --eval --pred_mode {PRED_MODE} --sampler {SAMPLER} --prior {PRIOR} \
--sigma_min {SIGMA_MIN} --sigma_max {SIGMA_MAX} --sigma_data {SIGMA_DATA} --beta_min {BETA_MIN} --beta_d {BETA_MAX}  --result_csv {RESULT} --model_matching "D_matching" \
--kernel_type {KERNEL_TYPE} --bw {BW} --var {VAR}
     
print(f'Trained with {NAME_}')
print('*'*20)
# Out:
# (0.2, 10, 0.1, 0.3) stock
# 2026-02-06 05:22:53.172084: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-06 05:22:53.202927: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.1 beta with 0.2 10.0
# pred with:  vp
# churn ratio 0.33
# {'overall': {'trainable': '287.49K', 'non_trainable': '0', 'total': '287.49K'}, 'model': {'trainable': '287.49K', 'non_trainable': '0', 'total': '287.49K'}}
# ...
