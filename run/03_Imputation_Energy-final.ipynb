# %%
import os
import warnings

warnings.filterwarnings("ignore")
if 'run' in os.getcwd():
    os.chdir('..')
    
os.environ["CUDA_VISIBLE_DEVICES"] = "0" # Possible GPUS

# %%
import numpy as np
import matplotlib.pyplot as plt

SAMPLE = 1 # conditional
MODE = "infill"
DATA = 'sine'
NAME = 'DiffusionTS-imp-linear'
PRED_MODE = 'vp'
SAMPLER = 'sde'
BETA_MIN = 0.1
BETA_MAX = 2
SIGMA_MIN = 0.0001
SIGMA_MAX = 1
PROPORTION = 0.9

best_hyperparams = {}
best_hyperparams['fmri'] = (0.1, 2, 0.5, 'uniform') #beta min, beta max, sigma, prior
best_hyperparams['energy'] = (0.2, 10, 0.1, 'mean')
best_hyperparams['etth'] = (0.2, 10, 0.1, 'mean')
best_hyperparams['mujoco'] = (0.1, 2, 0.5, 'mean')
best_hyperparams['sines'] = (0.1, 2, 0.5, 'uniform')
best_hyperparams['stock'] = (0.2, 10, 0.1, 'mean')

LENGTH = 48
DATA = 'energy'
OPTS = f"model.params.seq_length {LENGTH} dataloader.train_dataset.params.window {LENGTH} dataloader.test_dataset.params.window {LENGTH} model.params.d_model {4*LENGTH}"

# %%
for MISSING in [0.25, 0.5, 0.75]:
    for SIGMA_DATA in [0.05]:
        for BETA_MAX in [0.2]:
            for BETA_MIN in [0.1]:
                for DATA in ['energy']:
                    PRIOR = 'impt-linear'
                    NAME_ = DATA + "_" + PRED_MODE + "_" + SAMPLER +  "_" + NAME + "_" + PRIOR + "_BETA" + str(BETA_MIN) + "_" + str(BETA_MAX) + "sigma_data" + str(SIGMA_DATA) + "missing" +  str(MISSING)
                    # !python main.py --data {DATA} --name {NAME_} --sample {SAMPLE} --mode {MODE} --train --bridge_karras --pred_mode {PRED_MODE} --sampler {SAMPLER} --prior {PRIOR} \
                    --sigma_min {SIGMA_MIN} --sigma_max {SIGMA_MAX} --sigma_data {SIGMA_DATA} --beta_min {BETA_MIN} --beta_d {BETA_MAX} --proportion {PROPORTION} --missing_ratio {MISSING} {OPTS}
                    # !python main.py --data {DATA} --name {NAME_} --sample {SAMPLE} --mode {MODE} --bridge_karras --pred_mode {PRED_MODE} --sampler {SAMPLER} --prior {PRIOR} \
                    --sigma_min {SIGMA_MIN} --sigma_max {SIGMA_MAX} --sigma_data {SIGMA_DATA} --beta_min {BETA_MIN} --beta_d {BETA_MAX} --proportion {PROPORTION} --missing_ratio {MISSING} {OPTS}
                    print(f'Trained with {NAME_}')
                    print('*'*20)
# Out:
# 2026-02-05 13:55:06.277486: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-05 13:55:06.319496: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.05 beta with 0.1 0.2
# pred with:  vp
# churn ratio 0.33
# {'overall': {'trainable': '4.23M', 'non_trainable': '0', 'total': '4.23M'}, 'model': {'trainable': '4.23M', 'non_trainable': '0', 'total': '4.23M'}}
# energy_vp_sde_DiffusionTS-imp-linear_impt-linear_BETA0.1_0.2sigma_data0.05missing0.25: start training...
# loss: 6.346917: 100%|███████████████████| 25000/25000 [1:14:57<00:00,  2.60it/s]
# ============================================================
# ============================================================
#
# loss: 6.346917: 100%|███████████████████| 25000/25000 [1:14:57<00:00,  5.56it/s]
# training complete loss: 6.346917
# Training done, time: 4497.42
# 2026-02-05 15:10:30.838680: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-05 15:10:30.870900: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.05 beta with 0.1 0.2
# pred with:  vp
# churn ratio 0.33
# {'overall': {'trainable': '4.23M', 'non_trainable': '0', 'total': '4.23M'}, 'model': {'trainable': '4.23M', 'non_trainable': '0', 'total': '4.23M'}}
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 50.13
# (94464, 28)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 102.37
# (94464, 28)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 122.29
# (94464, 28)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 121.53
# (94464, 28)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 121.32
# (94464, 28)
# mean_squared_error_01_scaleFinal Score:  0.0016588998818034381 ± 3.4798737377636484e-05
# mean_squared_errorFinal Score:  15.211222627684217 ± 1.022205773804609
# mean_absolute_errorFinal Score:  0.4764796478628533 ± 0.00683727933677159
# mean_absolute_percentage_errorFinal Score:  916076638855.2828 ± 400238889675.8181
# Trained with energy_vp_sde_DiffusionTS-imp-linear_impt-linear_BETA0.1_0.2sigma_data0.05missing0.25
# ********************
# 2026-02-05 15:19:30.277132: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-05 15:19:30.309329: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.05 beta with 0.1 0.2
# pred with:  vp
# churn ratio 0.33
# {'overall': {'trainable': '4.23M', 'non_trainable': '0', 'total': '4.23M'}, 'model': {'trainable': '4.23M', 'non_trainable': '0', 'total': '4.23M'}}
# energy_vp_sde_DiffusionTS-imp-linear_impt-linear_BETA0.1_0.2sigma_data0.05missing0.5: start training...
# loss: 8.324264: 100%|███████████████████| 25000/25000 [1:16:22<00:00,  2.78it/s]
# ============================================================
# ============================================================
#
# loss: 8.324264: 100%|███████████████████| 25000/25000 [1:16:22<00:00,  5.46it/s]
# training complete loss: 8.324264
# Training done, time: 4582.12
# 2026-02-05 16:36:14.561966: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-05 16:36:14.592805: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.05 beta with 0.1 0.2
# pred with:  vp
# churn ratio 0.33
# {'overall': {'trainable': '4.23M', 'non_trainable': '0', 'total': '4.23M'}, 'model': {'trainable': '4.23M', 'non_trainable': '0', 'total': '4.23M'}}
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 27.78
# (94464, 28)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 25.30
# (94464, 28)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 25.53
# (94464, 28)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 28.46
# (94464, 28)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 36.48
# (94464, 28)
# mean_squared_error_01_scaleFinal Score:  0.002809186431794345 ± 5.067809095138688e-05
# mean_squared_errorFinal Score:  28.90271165245668 ± 2.54180400916983
# mean_absolute_errorFinal Score:  0.7060334445702761 ± 0.011238507708987357
# mean_absolute_percentage_errorFinal Score:  2173902303398.9387 ± 392600902199.95856
# Trained with energy_vp_sde_DiffusionTS-imp-linear_impt-linear_BETA0.1_0.2sigma_data0.05missing0.5
# ********************
# 2026-02-05 16:39:00.572198: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-05 16:39:00.603004: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.05 beta with 0.1 0.2
# pred with:  vp
# churn ratio 0.33
# {'overall': {'trainable': '4.23M', 'non_trainable': '0', 'total': '4.23M'}, 'model': {'trainable': '4.23M', 'non_trainable': '0', 'total': '4.23M'}}
# energy_vp_sde_DiffusionTS-imp-linear_impt-linear_BETA0.1_0.2sigma_data0.05missing0.75: start training...
# loss: 7.858123: 100%|███████████████████| 25000/25000 [1:15:56<00:00,  2.61it/s]
# ============================================================
# ============================================================
#
# loss: 7.858123: 100%|███████████████████| 25000/25000 [1:15:56<00:00,  5.49it/s]
# training complete loss: 7.858123
# Training done, time: 4556.61
# 2026-02-05 17:55:19.326260: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-05 17:55:19.356647: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.05 beta with 0.1 0.2
# pred with:  vp
# churn ratio 0.33
# {'overall': {'trainable': '4.23M', 'non_trainable': '0', 'total': '4.23M'}, 'model': {'trainable': '4.23M', 'non_trainable': '0', 'total': '4.23M'}}
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 33.62
# (94464, 28)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 29.10
# (94464, 28)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 41.30
# (94464, 28)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 34.59
# (94464, 28)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 30.23
# (94464, 28)
# mean_squared_error_01_scaleFinal Score:  0.004395659077707106 ± 3.012034546352084e-05
# mean_squared_errorFinal Score:  59.316972723835974 ± 1.8264949398471313
# mean_absolute_errorFinal Score:  1.0375957713286668 ± 0.009557596890094774
# mean_absolute_percentage_errorFinal Score:  5674289035943.533 ± 851567709484.9213
# Trained with energy_vp_sde_DiffusionTS-imp-linear_impt-linear_BETA0.1_0.2sigma_data0.05missing0.75
# ********************

# %%
# sampling only with TimeBridge-75%
for MISSING in [0.25, 0.5]:
    for SIGMA_DATA in [0.05]:
        for BETA_MAX in [0.2]:
            for BETA_MIN in [0.1]:
                for DATA in ['energy']:
                    PRIOR = 'impt-linear'
                    NAME_ = DATA + "_" + PRED_MODE + "_" + SAMPLER +  "_" + NAME + "_" + PRIOR + "_BETA" + str(BETA_MIN) + "_" + str(BETA_MAX) + "sigma_data" + str(SIGMA_DATA) + "missing" + "0.75"
                    # !python main.py --data {DATA} --name {NAME_} --sample {SAMPLE} --mode {MODE} --train --bridge_karras --pred_mode {PRED_MODE} --sampler {SAMPLER} --prior {PRIOR} \
                    # --sigma_min {SIGMA_MIN} --sigma_max {SIGMA_MAX} --sigma_data {SIGMA_DATA} --beta_min {BETA_MIN} --beta_d {BETA_MAX} --proportion {PROPORTION} --missing_ratio {MISSING} {OPTS}
                    # !python main.py --data {DATA} --name {NAME_} --sample {SAMPLE} --mode {MODE} --bridge_karras --pred_mode {PRED_MODE} --sampler {SAMPLER} --prior {PRIOR} \
                    --sigma_min {SIGMA_MIN} --sigma_max {SIGMA_MAX} --sigma_data {SIGMA_DATA} --beta_min {BETA_MIN} --beta_d {BETA_MAX} --proportion {PROPORTION} --missing_ratio {MISSING} {OPTS}
                    print(f'Trained with {NAME_}')
                    print('*'*20)
# Out:
# 2026-02-05 17:58:29.088588: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-05 17:58:29.120588: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.05 beta with 0.1 0.2
# pred with:  vp
# churn ratio 0.33
# {'overall': {'trainable': '4.23M', 'non_trainable': '0', 'total': '4.23M'}, 'model': {'trainable': '4.23M', 'non_trainable': '0', 'total': '4.23M'}}
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 41.49
# (94464, 28)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 28.35
# (94464, 28)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 23.85
# (94464, 28)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 24.24
# (94464, 28)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 23.65
# (94464, 28)
# mean_squared_error_01_scaleFinal Score:  0.001073018475318504 ± 4.391413448076614e-05
# mean_squared_errorFinal Score:  11.40138572540219 ± 0.9055823693571131
# mean_absolute_errorFinal Score:  0.4316937200952554 ± 0.004668967310821119
# mean_absolute_percentage_errorFinal Score:  1284283422845.1853 ± 257277042051.33923
# Trained with energy_vp_sde_DiffusionTS-imp-linear_impt-linear_BETA0.1_0.2sigma_data0.05missing0.75
# ********************
# 2026-02-05 18:01:11.432043: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-05 18:01:11.463697: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.05 beta with 0.1 0.2
# pred with:  vp
# churn ratio 0.33
# {'overall': {'trainable': '4.23M', 'non_trainable': '0', 'total': '4.23M'}, 'model': {'trainable': '4.23M', 'non_trainable': '0', 'total': '4.23M'}}
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 36.23
# (94464, 28)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 27.43
# (94464, 28)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 30.04
# (94464, 28)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 29.42
# (94464, 28)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 44.97
# (94464, 28)
# mean_squared_error_01_scaleFinal Score:  0.002271633555100851 ± 5.697835136746459e-05
# mean_squared_errorFinal Score:  21.80488154580997 ± 1.3662452763557098
# mean_absolute_errorFinal Score:  0.616307920131037 ± 0.008545101264421593
# mean_absolute_percentage_errorFinal Score:  2398538106272.002 ± 323007295879.19226
# Trained with energy_vp_sde_DiffusionTS-imp-linear_impt-linear_BETA0.1_0.2sigma_data0.05missing0.75
# ********************
