# %%
import os
import warnings

warnings.filterwarnings("ignore")
if 'run' in os.getcwd():
    os.chdir('..')
    
os.environ["CUDA_VISIBLE_DEVICES"] = "2" # Possible GPUS

# %%
import numpy as np
import matplotlib.pyplot as plt

SAMPLE = 1 # conditional
MODE = "infill"
DATA = 'sine'
NAME = 'DiffusionTS-imp-linear'
PRED_MODE = 'vp'
SAMPLER = 'sde'
BETA_MIN = 0.1
BETA_MAX = 2
SIGMA_MIN = 0.0001
SIGMA_MAX = 1
PROPORTION = 0.9

best_hyperparams = {}
best_hyperparams['fmri'] = (0.1, 2, 0.5, 'uniform') #beta min, beta max, sigma, prior
best_hyperparams['energy'] = (0.2, 10, 0.1, 'mean')
best_hyperparams['etth'] = (0.2, 10, 0.1, 'mean')
best_hyperparams['mujoco'] = (0.1, 2, 0.5, 'mean')
best_hyperparams['sines'] = (0.1, 2, 0.5, 'uniform')
best_hyperparams['stock'] = (0.2, 10, 0.1, 'mean')

# %%
LENGTH = 48

OPTS = f"model.params.seq_length {LENGTH} dataloader.train_dataset.params.window {LENGTH} dataloader.test_dataset.params.window {LENGTH} model.params.d_model {4*LENGTH}"

# %%
for MISSING in [0.25, 0.5, 0.75]:
    for SIGMA_DATA in [0.1]:
        for BETA_MAX in [0.2]:
            for BETA_MIN in [0.1]:
                for DATA in ['etth']:
                    PRIOR = 'impt-linear'
                    NAME_ = DATA + "_" + PRED_MODE + "_" + SAMPLER +  "_" + NAME + "_" + PRIOR + "_BETA" + str(BETA_MIN) + "_" + str(BETA_MAX) + "sigma_data" + str(SIGMA_DATA) + "missing" + str(MISSING)
                    # !python main.py --data {DATA} --name {NAME_} --sample {SAMPLE} --mode {MODE} --train --bridge_karras --pred_mode {PRED_MODE} --sampler {SAMPLER} --prior {PRIOR} \
                    --sigma_min {SIGMA_MIN} --sigma_max {SIGMA_MAX} --sigma_data {SIGMA_DATA} --beta_min {BETA_MIN} --beta_d {BETA_MAX} --proportion {PROPORTION} --missing_ratio {MISSING} {OPTS}
                    # !python main.py --data {DATA} --name {NAME_} --sample {SAMPLE} --mode {MODE} --bridge_karras --pred_mode {PRED_MODE} --sampler {SAMPLER} --prior {PRIOR} \
                    --sigma_min {SIGMA_MIN} --sigma_max {SIGMA_MAX} --sigma_data {SIGMA_DATA} --beta_min {BETA_MIN} --beta_d {BETA_MAX} --proportion {PROPORTION} --missing_ratio {MISSING} {OPTS}
                    print(f'Trained with {NAME_}')
                    print('*'*20)
# Out:
# 2026-02-05 09:13:32.161234: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-05 09:13:32.192401: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.1 beta with 0.1 0.2
# pred with:  vp
# churn ratio 0.33
# {'overall': {'trainable': '2.94M', 'non_trainable': '0', 'total': '2.94M'}, 'model': {'trainable': '2.94M', 'non_trainable': '0', 'total': '2.94M'}}
# etth_vp_sde_DiffusionTS-imp-linear_impt-linear_BETA0.1_0.2sigma_data0.1missing0.25: start training...
# loss: 3.997061: 100%|█████████████████████| 18000/18000 [38:48<00:00,  6.10it/s]
# ============================================================
# ============================================================
#
# loss: 3.997061: 100%|█████████████████████| 18000/18000 [38:48<00:00,  7.73it/s]
# training complete loss: 3.997061
# Training done, time: 2328.13
# 2026-02-05 09:52:33.607957: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-05 09:52:33.641585: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.1 beta with 0.1 0.2
# pred with:  vp
# churn ratio 0.33
# {'overall': {'trainable': '2.94M', 'non_trainable': '0', 'total': '2.94M'}, 'model': {'trainable': '2.94M', 'non_trainable': '0', 'total': '2.94M'}}
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 78.71
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 75.23
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 75.65
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 75.23
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 75.00
# (83376, 7)
# mean_squared_error_01_scaleFinal Score:  0.00024000110328648139 ± 9.614993856940376e-06
# mean_squared_errorFinal Score:  0.16981449120808959 ± 0.011185864968578135
# mean_absolute_errorFinal Score:  0.2204394000208009 ± 0.0015065084922779755
# mean_absolute_percentage_errorFinal Score:  0.20285566112700099 ± 0.028384255683676776
# Trained with etth_vp_sde_DiffusionTS-imp-linear_impt-linear_BETA0.1_0.2sigma_data0.1missing0.25
# ********************
# 2026-02-05 09:59:04.543196: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-05 09:59:04.580464: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.1 beta with 0.1 0.2
# pred with:  vp
# churn ratio 0.33
# {'overall': {'trainable': '2.94M', 'non_trainable': '0', 'total': '2.94M'}, 'model': {'trainable': '2.94M', 'non_trainable': '0', 'total': '2.94M'}}
# etth_vp_sde_DiffusionTS-imp-linear_impt-linear_BETA0.1_0.2sigma_data0.1missing0.5: start training...
# loss: 3.714361: 100%|█████████████████████| 18000/18000 [44:41<00:00,  6.03it/s]
# ============================================================
# ============================================================
#
# loss: 3.714361: 100%|█████████████████████| 18000/18000 [44:41<00:00,  6.71it/s]
# training complete loss: 3.714361
# Training done, time: 2681.91
# 2026-02-05 10:43:59.874628: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-05 10:43:59.910232: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.1 beta with 0.1 0.2
# pred with:  vp
# churn ratio 0.33
# {'overall': {'trainable': '2.94M', 'non_trainable': '0', 'total': '2.94M'}, 'model': {'trainable': '2.94M', 'non_trainable': '0', 'total': '2.94M'}}
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 74.22
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 70.80
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 70.31
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 69.96
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 69.12
# (83376, 7)
# mean_squared_error_01_scaleFinal Score:  0.0002580608968320628 ± 8.685099931737326e-06
# mean_squared_errorFinal Score:  0.17833003193818953 ± 0.007109596449024464
# mean_absolute_errorFinal Score:  0.21679234099337896 ± 0.0017368044826326825
# mean_absolute_percentage_errorFinal Score:  0.26284586128351345 ± 0.0936865635989936
# Trained with etth_vp_sde_DiffusionTS-imp-linear_impt-linear_BETA0.1_0.2sigma_data0.1missing0.5
# ********************
# 2026-02-05 10:50:05.325088: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-05 10:50:05.360245: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.1 beta with 0.1 0.2
# pred with:  vp
# churn ratio 0.33
# {'overall': {'trainable': '2.94M', 'non_trainable': '0', 'total': '2.94M'}, 'model': {'trainable': '2.94M', 'non_trainable': '0', 'total': '2.94M'}}
# etth_vp_sde_DiffusionTS-imp-linear_impt-linear_BETA0.1_0.2sigma_data0.1missing0.75: start training...
# loss: 4.054302: 100%|█████████████████████| 18000/18000 [41:35<00:00,  4.51it/s]
# ============================================================
# ============================================================
#
# loss: 4.054302: 100%|█████████████████████| 18000/18000 [41:35<00:00,  7.21it/s]
# training complete loss: 4.054302
# Training done, time: 2495.45
# 2026-02-05 11:31:53.473124: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-05 11:31:53.504510: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.1 beta with 0.1 0.2
# pred with:  vp
# churn ratio 0.33
# {'overall': {'trainable': '2.94M', 'non_trainable': '0', 'total': '2.94M'}, 'model': {'trainable': '2.94M', 'non_trainable': '0', 'total': '2.94M'}}
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 36.38
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 37.60
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 28.98
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 30.41
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 29.14
# (83376, 7)
# mean_squared_error_01_scaleFinal Score:  0.0007597002438324718 ± 1.8229234073697526e-05
# mean_squared_errorFinal Score:  0.6271929038160933 ± 0.026071081211905177
# mean_absolute_errorFinal Score:  0.3605627026284933 ± 0.005730450887303357
# mean_absolute_percentage_errorFinal Score:  0.7519746811750395 ± 0.9022375560980923
# Trained with etth_vp_sde_DiffusionTS-imp-linear_impt-linear_BETA0.1_0.2sigma_data0.1missing0.75
# ********************

# %%
# sampling only with TimeBridge-75%

for MISSING in [0,25, 0.5, 0.75]:
    for SIGMA_DATA in [0.1]:
        for BETA_MAX in [0.2]:
            for BETA_MIN in [0.1]:
                for DATA in ['etth']:
                    PRIOR = 'impt-linear'
                    NAME_ = DATA + "_" + PRED_MODE + "_" + SAMPLER +  "_" + NAME + "_" + PRIOR + "_BETA" + str(BETA_MIN) + "_" + str(BETA_MAX) + "sigma_data" + str(SIGMA_DATA) + "missing" + "0.75"
                    # !python main.py --data {DATA} --name {NAME_} --sample {SAMPLE} --mode {MODE} --train --bridge_karras --pred_mode {PRED_MODE} --sampler {SAMPLER} --prior {PRIOR} \
                    # --sigma_min {SIGMA_MIN} --sigma_max {SIGMA_MAX} --sigma_data {SIGMA_DATA} --beta_min {BETA_MIN} --beta_d {BETA_MAX} --proportion {PROPORTION} --missing_ratio {MISSING} {OPTS}
                    # !python main.py --data {DATA} --name {NAME_} --sample {SAMPLE} --mode {MODE} --bridge_karras --pred_mode {PRED_MODE} --sampler {SAMPLER} --prior {PRIOR} \
                    --sigma_min {SIGMA_MIN} --sigma_max {SIGMA_MAX} --sigma_data {SIGMA_DATA} --beta_min {BETA_MIN} --beta_d {BETA_MAX} --proportion {PROPORTION} --missing_ratio {MISSING} {OPTS}
                    print(f'Trained with {NAME_}')
                    print('*'*20)
# Out:
# 2026-02-05 13:54:41.900347: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-05 13:54:41.931438: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.1 beta with 0.1 0.2
# pred with:  vp
# churn ratio 0.33
# {'overall': {'trainable': '2.94M', 'non_trainable': '0', 'total': '2.94M'}, 'model': {'trainable': '2.94M', 'non_trainable': '0', 'total': '2.94M'}}
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 38.71
# (83376, 7)
# Traceback (most recent call last):
#   File "main.py", line 342, in <module>
#     main()
#   File "main.py", line 220, in main
#     mse_01 = mean_squared_error(samples[~masks], reals[~masks])
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/metrics/_regression.py", line 474, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/metrics/_regression.py", line 100, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py", line 967, in check_array
#     raise ValueError(
# ValueError: Found array with 0 sample(s) (shape=(0,)) while a minimum of 1 is required.
# Trained with etth_vp_sde_DiffusionTS-imp-linear_impt-linear_BETA0.1_0.2sigma_data0.1missing0.75
# ********************
# 2026-02-05 13:55:30.336608: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-05 13:55:30.370003: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.1 beta with 0.1 0.2
# pred with:  vp
# churn ratio 0.33
# {'overall': {'trainable': '2.94M', 'non_trainable': '0', 'total': '2.94M'}, 'model': {'trainable': '2.94M', 'non_trainable': '0', 'total': '2.94M'}}
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 48.41
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 39.74
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 40.97
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 39.96
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 38.09
# (83376, 7)
# mean_squared_error_01_scaleFinal Score:  0.0007170428450826252 ± 2.2219371058815905e-05
# mean_squared_errorFinal Score:  0.544010347280363 ± 0.01890480770341272
# mean_absolute_errorFinal Score:  0.3786960785736594 ± 0.004215318271086578
# mean_absolute_percentage_errorFinal Score:  0.3998126146705449 ± 0.1502483972748189
# Trained with etth_vp_sde_DiffusionTS-imp-linear_impt-linear_BETA0.1_0.2sigma_data0.1missing0.75
# ********************
# 2026-02-05 13:59:08.035855: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-05 13:59:08.068517: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.1 beta with 0.1 0.2
# pred with:  vp
# churn ratio 0.33
# {'overall': {'trainable': '2.94M', 'non_trainable': '0', 'total': '2.94M'}, 'model': {'trainable': '2.94M', 'non_trainable': '0', 'total': '2.94M'}}
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 33.71
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 31.70
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 28.12
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 30.14
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 30.85
# (83376, 7)
# mean_squared_error_01_scaleFinal Score:  0.0002916478750398893 ± 9.548725262472763e-06
# mean_squared_errorFinal Score:  0.1972694331835178 ± 0.0042033059611479556
# mean_absolute_errorFinal Score:  0.23836065024342737 ± 0.001162268355406519
# mean_absolute_percentage_errorFinal Score:  0.2413659714839088 ± 0.053303946121731435
# Trained with etth_vp_sde_DiffusionTS-imp-linear_impt-linear_BETA0.1_0.2sigma_data0.1missing0.75
# ********************
# 2026-02-05 14:01:53.538062: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-05 14:01:53.571662: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.1 beta with 0.1 0.2
# pred with:  vp
# churn ratio 0.33
# {'overall': {'trainable': '2.94M', 'non_trainable': '0', 'total': '2.94M'}, 'model': {'trainable': '2.94M', 'non_trainable': '0', 'total': '2.94M'}}
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 40.83
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 40.66
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 37.36
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 47.77
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 41.25
# (83376, 7)
# mean_squared_error_01_scaleFinal Score:  0.0007597002438324718 ± 1.8229234073697526e-05
# mean_squared_errorFinal Score:  0.6271929038160933 ± 0.026071081211905177
# mean_absolute_errorFinal Score:  0.3605627026284933 ± 0.005730450887303357
# mean_absolute_percentage_errorFinal Score:  0.7519746811750395 ± 0.9022375560980923
# Trained with etth_vp_sde_DiffusionTS-imp-linear_impt-linear_BETA0.1_0.2sigma_data0.1missing0.75
# ********************
