# %%
import os
import warnings

warnings.filterwarnings("ignore")
if 'run' in os.getcwd():
    os.chdir('..')
    
os.environ["CUDA_VISIBLE_DEVICES"] = "2" # Possible GPUS

# %%
import numpy as np
import matplotlib.pyplot as plt

SAMPLE = 1 # conditional
MODE = "infill"
DATA = 'sine'
NAME = 'DiffusionTS-imp-linear'
PRED_MODE = 'vp'
SAMPLER = 'sde'
BETA_MIN = 0.1
BETA_MAX = 2
SIGMA_MIN = 0.0001
SIGMA_MAX = 1
PROPORTION = 0.9

best_hyperparams = {}
best_hyperparams['fmri'] = (0.1, 2, 0.5, 'uniform') #beta min, beta max, sigma, prior
best_hyperparams['energy'] = (0.2, 10, 0.1, 'mean')
best_hyperparams['etth'] = (0.2, 10, 0.1, 'mean')
best_hyperparams['mujoco'] = (0.1, 2, 0.5, 'mean')
best_hyperparams['sines'] = (0.1, 2, 0.5, 'uniform')
best_hyperparams['stock'] = (0.2, 10, 0.1, 'mean')

# %%
LENGTH = 48

OPTS = f"model.params.seq_length {LENGTH} dataloader.train_dataset.params.window {LENGTH} dataloader.test_dataset.params.window {LENGTH} model.params.d_model {4*LENGTH}"

# %%
for MISSING in [0.25, 0.5, 0.75]:
    for SIGMA_DATA in [0.1]:
        for BETA_MAX in [0.2]:
            for BETA_MIN in [0.1]:
                for DATA in ['etth']:
                    PRIOR = 'impt-linear'
                    NAME_ = DATA + "_" + PRED_MODE + "_" + SAMPLER +  "_" + NAME + "_" + PRIOR + "_BETA" + str(BETA_MIN) + "_" + str(BETA_MAX) + "sigma_data" + str(SIGMA_DATA) + "missing" + str(MISSING)
                    # !python main.py --data {DATA} --name {NAME_} --sample {SAMPLE} --mode {MODE} --train --bridge_karras --pred_mode {PRED_MODE} --sampler {SAMPLER} --prior {PRIOR} \
                    --sigma_min {SIGMA_MIN} --sigma_max {SIGMA_MAX} --sigma_data {SIGMA_DATA} --beta_min {BETA_MIN} --beta_d {BETA_MAX} --proportion {PROPORTION} --missing_ratio {MISSING} {OPTS}
                    # !python main.py --data {DATA} --name {NAME_} --sample {SAMPLE} --mode {MODE} --bridge_karras --pred_mode {PRED_MODE} --sampler {SAMPLER} --prior {PRIOR} \
                    --sigma_min {SIGMA_MIN} --sigma_max {SIGMA_MAX} --sigma_data {SIGMA_DATA} --beta_min {BETA_MIN} --beta_d {BETA_MAX} --proportion {PROPORTION} --missing_ratio {MISSING} {OPTS}
                    print(f'Trained with {NAME_}')
                    print('*'*20)
# Out:
# 2024-05-15 08:51:36.358872: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-15 08:51:36.434373: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-15 08:51:37.425373: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.1 beta with 0.1 0.2
# pred with:  vp
# churn ratio 0.33
# {'overall': {'trainable': '2.94M', 'non_trainable': '0', 'total': '2.94M'}, 'model': {'trainable': '2.94M', 'non_trainable': '0', 'total': '2.94M'}}
# Begin to restore...
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Imputation done, time: 49.62
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Imputation done, time: 48.67
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Imputation done, time: 49.48
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Imputation done, time: 50.07
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Imputation done, time: 50.74
# (83376, 7)
# mean_squared_error_01_scaleFinal Score:  0.00023484991104635216 ± 9.887678197987497e-06
# mean_squared_errorFinal Score:  0.15970829390878435 ± 0.014326195351981966
# mean_absolute_errorFinal Score:  0.21982308809347034 ± 0.0014062691473377812
# mean_absolute_percentage_errorFinal Score:  0.20677400317280745 ± 0.03400949607516424
# Trained with etth_vp_sde_DiffusionTS-imp-linear_impt-linear_BETA0.1_0.2sigma_data0.1missing0.25
# ********************
# 2024-05-15 08:55:57.117404: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-15 08:55:57.165570: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-15 08:55:57.888103: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.1 beta with 0.1 0.2
# pred with:  vp
# churn ratio 0.33
# {'overall': {'trainable': '2.94M', 'non_trainable': '0', 'total': '2.94M'}, 'model': {'trainable': '2.94M', 'non_trainable': '0', 'total': '2.94M'}}
# Begin to restore...
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Imputation done, time: 46.35
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Imputation done, time: 45.77
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Imputation done, time: 53.74
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Imputation done, time: 79.83
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Imputation done, time: 81.44
# (83376, 7)
# mean_squared_error_01_scaleFinal Score:  0.0002762698823944675 ± 1.3728056555267605e-05
# mean_squared_errorFinal Score:  0.1886849920914182 ± 0.007929009558833636
# mean_absolute_errorFinal Score:  0.2175077474227262 ± 0.0012113132617269458
# mean_absolute_percentage_errorFinal Score:  0.284075811516335 ± 0.1979919262647707
# Trained with etth_vp_sde_DiffusionTS-imp-linear_impt-linear_BETA0.1_0.2sigma_data0.1missing0.5
# ********************
# 2024-05-15 09:01:16.190685: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-15 09:01:16.268481: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-15 09:01:17.453760: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.1 beta with 0.1 0.2
# pred with:  vp
# churn ratio 0.33
# {'overall': {'trainable': '2.94M', 'non_trainable': '0', 'total': '2.94M'}, 'model': {'trainable': '2.94M', 'non_trainable': '0', 'total': '2.94M'}}
# Begin to restore...
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Imputation done, time: 74.29
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Imputation done, time: 67.97
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Imputation done, time: 74.07
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Imputation done, time: 73.09
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Sampling time steps 40
# Imputation done, time: 66.84
# (83376, 7)
# mean_squared_error_01_scaleFinal Score:  0.0007728694356624328 ± 1.7093695025549504e-05
# mean_squared_errorFinal Score:  0.6409120200930826 ± 0.02904242980452728
# mean_absolute_errorFinal Score:  0.3556213719448066 ± 0.004172314549861763
# mean_absolute_percentage_errorFinal Score:  0.38112440602335945 ± 0.09019399074646946
# Trained with etth_vp_sde_DiffusionTS-imp-linear_impt-linear_BETA0.1_0.2sigma_data0.1missing0.75
# ********************

# %%
# sampling only with TimeBridge-75%

for MISSING in [0.75]:
    for SIGMA_DATA in [0.1]:
        for BETA_MAX in [0.2]:
            for BETA_MIN in [0.1]:
                for DATA in ['etth']:
                    PRIOR = 'impt-linear'
                    NAME_ = DATA + "_" + PRED_MODE + "_" + SAMPLER +  "_" + NAME + "_" + PRIOR + "_BETA" + str(BETA_MIN) + "_" + str(BETA_MAX) + "sigma_data" + str(SIGMA_DATA) + "missing" + "0.75"
                    # !python main.py --data {DATA} --name {NAME_} --sample {SAMPLE} --mode {MODE} --train --bridge_karras --pred_mode {PRED_MODE} --sampler {SAMPLER} --prior {PRIOR} \
                    # --sigma_min {SIGMA_MIN} --sigma_max {SIGMA_MAX} --sigma_data {SIGMA_DATA} --beta_min {BETA_MIN} --beta_d {BETA_MAX} --proportion {PROPORTION} --missing_ratio {MISSING} {OPTS}
                    # !python main.py --data {DATA} --name {NAME_} --sample {SAMPLE} --mode {MODE} --bridge_karras --pred_mode {PRED_MODE} --sampler {SAMPLER} --prior {PRIOR} \
                    --sigma_min {SIGMA_MIN} --sigma_max {SIGMA_MAX} --sigma_data {SIGMA_DATA} --beta_min {BETA_MIN} --beta_d {BETA_MAX} --proportion {PROPORTION} --missing_ratio {MISSING} {OPTS}
                    print(f'Trained with {NAME_}')
                    print('*'*20)
# Out:
# 2024-05-18 13:09:37.810580: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-18 13:09:37.961327: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-18 13:09:39.499732: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.1 beta with 0.1 0.2
# pred with:  vp
# churn ratio 0.33
# {'overall': {'trainable': '2.94M', 'non_trainable': '0', 'total': '2.94M'}, 'model': {'trainable': '2.94M', 'non_trainable': '0', 'total': '2.94M'}}
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 119.64
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 152.85
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 126.57
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 157.44
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 116.10
# (83376, 7)
# mean_squared_error_01_scaleFinal Score:  0.0007728694356624328 ± 1.7093695025549504e-05
# mean_squared_errorFinal Score:  0.6409120200930826 ± 0.02904242980452728
# mean_absolute_errorFinal Score:  0.3556213719448066 ± 0.004172314549861763
# mean_absolute_percentage_errorFinal Score:  0.38112440602335945 ± 0.09019399074646946
# Trained with etth_vp_sde_DiffusionTS-imp-linear_impt-linear_BETA0.1_0.2sigma_data0.1missing0.75
# ********************
