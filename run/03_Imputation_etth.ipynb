# %%
import os
import warnings

warnings.filterwarnings("ignore")
if 'run' in os.getcwd():
    os.chdir('..')
    
os.environ["CUDA_VISIBLE_DEVICES"] = "2" # Possible GPUS

# %%
import numpy as np
import matplotlib.pyplot as plt

SAMPLE = 1 # conditional
MODE = "infill"
NAME = 'DiffusionTS-imp-linear'
PRED_MODE = 'vp'
SAMPLER = 'sde'
SIGMA_MIN = 0.0001
SIGMA_MAX = 1
PROPORTION = 0.9

# %%
best_hyperparams = {}
best_hyperparams['fmri'] = (0.1, 2, 0.5, 'uniform') #beta min, beta max, sigma, prior
best_hyperparams['energy'] = (0.2, 10, 0.1, 'mean')
best_hyperparams['etth'] = (0.2, 10, 0.1, 'mean')
best_hyperparams['mujoco'] = (0.1, 2, 0.5, 'mean')
best_hyperparams['sines'] = (0.1, 2, 0.5, 'uniform')
best_hyperparams['stock'] = (0.2, 10, 0.1, 'mean')

# %%
DATA = 'etth'
MISSING = 0.75

# %%
BETA_MIN = best_hyperparams[DATA][0]
BETA_MAX = best_hyperparams[DATA][1]
SIGMA_DATA = best_hyperparams[DATA][2]
LENGTH = 48
OPTS = f"model.params.seq_length {LENGTH} dataloader.train_dataset.params.window {LENGTH} dataloader.test_dataset.params.window {LENGTH} model.params.d_model {4*LENGTH}"

# %%
PRIOR = 'impt-linear'
NAME_ = DATA + "_" + PRED_MODE + "_" + SAMPLER +  "_" + NAME + "_" + PRIOR + "_BETA" + str(BETA_MIN) + "_" + str(BETA_MAX) + "sigma_data" + str(SIGMA_DATA) + "missing" + str(MISSING)
# !python main.py --data {DATA} --name {NAME_} --sample {SAMPLE} --mode {MODE} --train --bridge_karras --pred_mode {PRED_MODE} --sampler {SAMPLER} --prior {PRIOR} \
--sigma_min {SIGMA_MIN} --sigma_max {SIGMA_MAX} --sigma_data {SIGMA_DATA} --beta_min {BETA_MIN} --beta_d {BETA_MAX} --proportion {PROPORTION} --missing_ratio {MISSING} {OPTS}
# !python main.py --data {DATA} --name {NAME_} --sample {SAMPLE} --mode {MODE} --bridge_karras --pred_mode {PRED_MODE} --sampler {SAMPLER} --prior {PRIOR} \
--sigma_min {SIGMA_MIN} --sigma_max {SIGMA_MAX} --sigma_data {SIGMA_DATA} --beta_min {BETA_MIN} --beta_d {BETA_MAX} --proportion {PROPORTION} --missing_ratio {MISSING} {OPTS}
print(f'Trained with {NAME_}')
print('*'*20)
# Out:
# 2026-02-05 04:32:56.078605: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-05 04:32:56.110135: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.1 beta with 0.2 10.0
# pred with:  vp
# churn ratio 0.33
# {'overall': {'trainable': '2.94M', 'non_trainable': '0', 'total': '2.94M'}, 'model': {'trainable': '2.94M', 'non_trainable': '0', 'total': '2.94M'}}
# etth_vp_sde_DiffusionTS-imp-linear_impt-linear_BETA0.2_10sigma_data0.1missing0.75: start training...
# loss: 13.733228: 100%|████████████████████| 18000/18000 [39:59<00:00,  4.71it/s]
# ============================================================
# ============================================================
#
# loss: 13.733228: 100%|████████████████████| 18000/18000 [39:59<00:00,  7.50it/s]
# training complete loss: 13.733228
# Training done, time: 2399.87
# 2026-02-05 05:13:07.953888: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-05 05:13:07.984792: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Global seed set to 12345
# lr with 1e-05
# sigma with 0.0001 1.0 0.1 beta with 0.2 10.0
# pred with:  vp
# churn ratio 0.33
# {'overall': {'trainable': '2.94M', 'non_trainable': '0', 'total': '2.94M'}, 'model': {'trainable': '2.94M', 'non_trainable': '0', 'total': '2.94M'}}
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 19.57
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 15.46
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 16.94
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 17.28
# (83376, 7)
# Begin to restore...
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Sampling time steps 40
# sampling with NFE: 119
# Imputation done, time: 17.67
# (83376, 7)
# mean_squared_error_01_scaleFinal Score:  0.00718038079427275 ± 0.00016557325446252638
# mean_squared_errorFinal Score:  6.845903128845876 ± 0.17693379822384578
# mean_absolute_errorFinal Score:  1.3752078565222328 ± 0.018992275964829657
# mean_absolute_percentage_errorFinal Score:  3.053760079251769 ± 3.6993961937108772
# Trained with etth_vp_sde_DiffusionTS-imp-linear_impt-linear_BETA0.2_10sigma_data0.1missing0.75
# ********************
