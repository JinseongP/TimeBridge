# %%
import os
import warnings


warnings.filterwarnings("ignore")
if 'run' in os.getcwd():
    os.chdir('..')
    
os.environ["CUDA_VISIBLE_DEVICES"] = "1" # Possible GPUS

# %%
SAMPLE = 0 # unconditional
MODE = 'generation'
NAME = 'energy'
PRIOR = 'trend'

# %%
# !CUDA_VISIBLE_DEVICES=0 python main.py --name {NAME} --sample {SAMPLE} --mode {MODE} --train --prior {PRIOR}
# !CUDA_VISIBLE_DEVICES=0 python main.py --name {NAME} --sample {SAMPLE} --mode {MODE} --eval --prior {PRIOR}

# %%
PRIOR = 'trend-linear'

# %%
# !CUDA_VISIBLE_DEVICES=0 python main.py --name {NAME} --sample {SAMPLE} --mode {MODE} --train --prior {PRIOR}
# !CUDA_VISIBLE_DEVICES=0 python main.py --name {NAME} --sample {SAMPLE} --mode {MODE} --eval --prior {PRIOR}
