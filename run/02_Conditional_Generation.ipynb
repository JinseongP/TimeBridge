# %%
import os
import warnings

warnings.filterwarnings("ignore")
if 'run' in os.getcwd():
    os.chdir('..')
    
os.environ["CUDA_VISIBLE_DEVICES"] = "2" # Possible GPUS

# %%
SAMPLE = 0 # conditional
MODE = "generation"
NAME = 'cond'
PRED_MODE = 'vp'
SAMPLER = 'sde'
SIGMA_MIN = 0.0001
SIGMA_MAX = 1

# %%
best_hyperparams = {}

# %%
#BETA_MIN, BETA_MAX, SIGMA_DATA
best_hyperparams['energy'] = (0.1, 0.2, 0.05)
best_hyperparams['etth'] = (0.1, 0.2, 0.1)

# %%
NAME = 'BRIDGE-TS-COND-BEST'
PRIOR = 'trend'

for DATA in ['energy', 'etth']:
    BETA_MIN, BETA_MAX, SIGMA_DATA = best_hyperparams[DATA]
    print(best_hyperparams[DATA], DATA)
    
    NAME_ = DATA + "_" + PRED_MODE + "_" + SAMPLER + "_" + NAME + "_" + PRIOR + "_" + str(BETA_MIN) + "_" + str(BETA_MAX)+"_"+ str(SIGMA_DATA) 
    
    # !python main.py --data {DATA} --name {NAME_} --sample {SAMPLE} --mode {MODE} --train --pred_mode {PRED_MODE} --sampler {SAMPLER} --prior {PRIOR} \
    --sigma_min {SIGMA_MIN} --sigma_max {SIGMA_MAX} --sigma_data {SIGMA_DATA} --beta_min {BETA_MIN} --beta_d {BETA_MAX}  --result_csv {RESULT} --model_matching "D_matching"

    # !python main.py --data {DATA} --name {NAME_} --sample {SAMPLE} --mode {MODE} --eval --pred_mode {PRED_MODE} --sampler {SAMPLER} --prior {PRIOR} \
    --sigma_min {SIGMA_MIN} --sigma_max {SIGMA_MAX} --sigma_data {SIGMA_DATA} --beta_min {BETA_MIN} --beta_d {BETA_MAX}  --result_csv {RESULT} --model_matching "D_matching"

     
print(f'Trained with {NAME_}')
print('*'*20)
# Out:
# (0.1, 0.2, 0.05) energy
# 2026-02-05 05:27:29.345713: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-05 05:27:29.376255: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# usage: main.py [-h] [--name NAME] [--data DATA] [--output OUTPUT]
#                [--tensorboard] [--cudnn_deterministic] [--seed SEED]
#                [--gpu GPU] [--train] [--sample {0,1}] [--mode MODE]
#                [--milestone MILESTONE] [--missing_ratio MISSING_RATIO]
#                [--pred_len PRED_LEN] [--eval] [--iteration ITERATION]
#                [--bridge_karras] [--pred_mode PRED_MODE] [--sampler SAMPLER]
#                [--prior PRIOR] [--pretrain]
#                [--pretrain_sampling PRETRAIN_SAMPLING]
#                [--config_suffix CONFIG_SUFFIX] [--lr LR]
#                [--result_csv RESULT_CSV] [--sigma_min SIGMA_MIN]
#                [--sigma_max SIGMA_MAX] [--sigma_data SIGMA_DATA]
#                [--beta_min BETA_MIN] [--beta_d BETA_D]
#                [--model_matching MODEL_MATCHING] [--proportion PROPORTION]
#                [--cond_embedding] [--var VAR] [--bw BW]
#                [--kernel_type KERNEL_TYPE]
#                [--use_img_transform USE_IMG_TRANSFORM]
#                [--img_transform_type {delay,stft}]
#                [--delay_embed_dim DELAY_EMBED_DIM]
#                [--delay_time_delay DELAY_TIME_DELAY] [--stft_n_fft STFT_N_FFT]
#                [--stft_hop_length STFT_HOP_LENGTH]
#                ...
# main.py: error: argument --sample: invalid int value: '{SAMPLE}'
# (0.1, 0.2, 0.1) etth
# 2026-02-05 05:27:36.221246: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-05 05:27:36.251881: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# usage: main.py [-h] [--name NAME] [--data DATA] [--output OUTPUT]
#                [--tensorboard] [--cudnn_deterministic] [--seed SEED]
#                [--gpu GPU] [--train] [--sample {0,1}] [--mode MODE]
#                [--milestone MILESTONE] [--missing_ratio MISSING_RATIO]
#                [--pred_len PRED_LEN] [--eval] [--iteration ITERATION]
#                [--bridge_karras] [--pred_mode PRED_MODE] [--sampler SAMPLER]
#                [--prior PRIOR] [--pretrain]
#                [--pretrain_sampling PRETRAIN_SAMPLING]
#                [--config_suffix CONFIG_SUFFIX] [--lr LR]
#                [--result_csv RESULT_CSV] [--sigma_min SIGMA_MIN]
#                [--sigma_max SIGMA_MAX] [--sigma_data SIGMA_DATA]
#                [--beta_min BETA_MIN] [--beta_d BETA_D]
#                [--model_matching MODEL_MATCHING] [--proportion PROPORTION]
#                [--cond_embedding] [--var VAR] [--bw BW]
#                [--kernel_type KERNEL_TYPE]
#                [--use_img_transform USE_IMG_TRANSFORM]
#                [--img_transform_type {delay,stft}]
#                [--delay_embed_dim DELAY_EMBED_DIM]
#                [--delay_time_delay DELAY_TIME_DELAY] [--stft_n_fft STFT_N_FFT]
#                [--stft_hop_length STFT_HOP_LENGTH]
#                ...
# main.py: error: argument --sample: invalid int value: '{SAMPLE}'
# 2026-02-05 05:27:41.357089: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-05 05:27:41.388075: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# usage: main.py [-h] [--name NAME] [--data DATA] [--output OUTPUT]
#                [--tensorboard] [--cudnn_deterministic] [--seed SEED]
#                [--gpu GPU] [--train] [--sample {0,1}] [--mode MODE]
#                [--milestone MILESTONE] [--missing_ratio MISSING_RATIO]
#                [--pred_len PRED_LEN] [--eval] [--iteration ITERATION]
#                [--bridge_karras] [--pred_mode PRED_MODE] [--sampler SAMPLER]
#                [--prior PRIOR] [--pretrain]
#                [--pretrain_sampling PRETRAIN_SAMPLING]
#                [--config_suffix CONFIG_SUFFIX] [--lr LR]
#                [--result_csv RESULT_CSV] [--sigma_min SIGMA_MIN]
#                [--sigma_max SIGMA_MAX] [--sigma_data SIGMA_DATA]
#                [--beta_min BETA_MIN] [--beta_d BETA_D]
#                [--model_matching MODEL_MATCHING] [--proportion PROPORTION]
#                [--cond_embedding] [--var VAR] [--bw BW]
#                [--kernel_type KERNEL_TYPE]
#                [--use_img_transform USE_IMG_TRANSFORM]
#                [--img_transform_type {delay,stft}]
#                [--delay_embed_dim DELAY_EMBED_DIM]
#                [--delay_time_delay DELAY_TIME_DELAY] [--stft_n_fft STFT_N_FFT]
#                [--stft_hop_length STFT_HOP_LENGTH]
#                ...
# main.py: error: argument --sample: invalid int value: '{SAMPLE}'
# Trained with etth_vp_sde_BRIDGE-TS-COND-BEST_trend_0.1_0.2_0.1
# ********************
